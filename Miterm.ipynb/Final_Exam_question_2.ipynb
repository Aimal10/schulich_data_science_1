# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aimaldastagirzada/Downloads/8a89caa9-511c-4568-af89-7f2174b4378c.csv')

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...

# %%
df['total_individuals_3doses'] = df['total_individuals_3doses'].astype(int)

# %%
df["new_doses"] = df["total_doses_administered"] - df["previous_day_total_doses_administered"]

# %%
df['new_doses_unvaccinated']= (df['total_doses_administered'] - df['total_individuals_at_least_one']).diff(1)

# %%
df['new_doses_one_vaccine']= (df['total_individuals_at_least_one'] - df['total_individuals_fully_vaccinated']).diff(1)

# %%
df['new_doses_two_vaccines']= (df['total_individuals_fully_vaccinated'] - df['total_individuals_3doses']).diff(1)

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...

# %%
df['new_doses_one_vaccine'] = (df['total_individuals_at_least_one']-df['total_individuals_fully_vaccinated']) - (df['previous_day_at_least_one']-df['previous_day_fully_vaccinated'])

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...

# %%
df['new_doses_two_vaccines'] = (df['total_individuals_fully_vaccinated']-df['total_individuals_3doses']) - (df['previous_day_fully_vaccinated']-df['previous_day_3doses'])

# %%
df["new_doses_three_vaccines"] = df["previous_day_3doses"]

# %%
df["new_doses_three_vaccines"] = df["total_individuals_3doses"].diff(1)

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...
