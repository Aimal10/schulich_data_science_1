# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aimaldastagirzada/Downloads/8a89caa9-511c-4568-af89-7f2174b4378c.csv')

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   _id                                          945 non-null    int64
#  1   report_date                                  945 non-null    object
#  2   previous_day_total_doses_administered        945 non-null    int64
#  3   previous_day_at_least_one                    945 non-null    int64
#  4   previous_day_fully_vaccinated                945 non-null    int64
#  5   previous_day_3doses                          608 non-null    float64
#  6   total_doses_administered                     945 non-null    int64
#  7   total_individuals_at_least_one               945 non-null    int64
#  8   total_individuals_partially_vaccinated       945 non-null    int64
# ...

# %%
import pandas as pd


# Calculate New Doses Administered
df['new_doses'] = df['total_doses_administered'].diff(1)

# Calculate New Doses for Unvaccinated
df['new_doses_unvaccinated'] = df['total_individuals_at_least_one'].diff(1)

# Calculate New Doses for People with One Vaccine
df['new_doses_one_vaccine'] = (df['total_individuals_partially_vaccinated']
                               - df['total_individuals_at_least_one']).diff()

# Calculate New Doses for People with Two Vaccines
df['new_doses_two_vaccines'] = (df['total_individuals_fully_vaccinated']
                                - df['total_individuals_partially_vaccinated']).diff()

# Calculate New Doses for People with Three Vaccines
df['new_doses_three_vaccines'] = (df['total_individuals_3doses']
                                  - df['total_individuals_fully_vaccinated']).diff()

# Print or analyze the resulting DataFrame
print(df[['report_date', 'new_doses', 'new_doses_unvaccinated', 'new_doses_one_vaccine', 'new_doses_two_vaccines', 'new_doses_three_vaccines']])
# Out:
#              report_date  new_doses  new_doses_unvaccinated
# 0    2021-01-01T00:00:00        NaN                     NaN  \
# 1    2021-01-02T00:00:00     4615.0                  4551.0
# 2    2021-01-03T00:00:00     5396.0                  5389.0
# 3    2021-01-04T00:00:00     5995.0                  5992.0
# 4    2021-01-05T00:00:00     9687.0                  9660.0
# ..                   ...        ...                     ...
# 940  2023-07-30T00:00:00      623.0                    27.0
# 941  2023-07-31T00:00:00      226.0                     6.0
# 942  2023-08-01T00:00:00     1085.0                    43.0
# 943  2023-08-02T00:00:00     1395.0                    72.0
# 944  2023-08-03T00:00:00     1016.0                    61.0
#
#      new_doses_one_vaccine  new_doses_two_vaccines  new_doses_three_vaccines
# 0                      NaN                     NaN                       NaN
# 1                     -2.0                 -4547.0                       NaN
# ...

# %%
print(df[['report_date']])
# Out:
#              report_date
# 0    2021-01-01T00:00:00
# 1    2021-01-02T00:00:00
# 2    2021-01-03T00:00:00
# 3    2021-01-04T00:00:00
# 4    2021-01-05T00:00:00
# ..                   ...
# 940  2023-07-30T00:00:00
# 941  2023-07-31T00:00:00
# 942  2023-08-01T00:00:00
# 943  2023-08-02T00:00:00
# 944  2023-08-03T00:00:00
#
# [945 rows x 1 columns]

# %%
print(df[['report_date', 'new_doses']])
# Out:
#              report_date  new_doses
# 0    2021-01-01T00:00:00        NaN
# 1    2021-01-02T00:00:00     4615.0
# 2    2021-01-03T00:00:00     5396.0
# 3    2021-01-04T00:00:00     5995.0
# 4    2021-01-05T00:00:00     9687.0
# ..                   ...        ...
# 940  2023-07-30T00:00:00      623.0
# 941  2023-07-31T00:00:00      226.0
# 942  2023-08-01T00:00:00     1085.0
# 943  2023-08-02T00:00:00     1395.0
# 944  2023-08-03T00:00:00     1016.0
#
# [945 rows x 2 columns]

# %%
df['new_doses_unvaccinated'] = df['total_individuals_at_least_one'].diff()

# %%
df['new_doses'] = df['total_doses_administered'].diff()

# %%
df
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 0      1  2021-01-01T00:00:00                                   6252  \
# 1      2  2021-01-02T00:00:00                                   4615
# 2      3  2021-01-03T00:00:00                                   5396
# 3      4  2021-01-04T00:00:00                                   5995
# 4      5  2021-01-05T00:00:00                                   9687
# ..   ...                  ...                                    ...
# 940  941  2023-07-30T00:00:00                                    623
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 0                         6242                              2  \
# ...
