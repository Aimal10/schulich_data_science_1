# %%
import pandas as pd

# %%
df =pd.read_csv('/Users/aimaldastagirzada/Downloads/messy_data (2).csv')

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df = pd.read_csv('/Users/aimaldastagirzada/Downloads/sales_data.csv')

# %%
df
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_6   75.96        10.0  2022-01-01
# 1            NaN  Region_1  175.78         8.0  2022-01-02
# 2     Product_46  Region_3   20.43        12.0  2022-01-03
# 3     Product_36  Region_1   12.77        10.0  2022-01-04
# 4     Product_17  Region_6  125.69         6.0  2022-01-05
# ...          ...       ...     ...         ...         ...
# 1045  Product_45  Region_7   78.69         8.0  2022-07-28
# 1046   Product_1  Region_6     NaN         8.0  2022-08-02
# 1047  Product_17  Region_2  114.37        11.0  2023-12-18
# 1048         NaN  Region_8     NaN         5.0  2023-12-27
# 1049  Product_16  Region_2   69.30         8.0  2024-02-23
#
# [1050 rows x 5 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_6   75.96        10.0  2022-01-01
# 1            NaN  Region_1  175.78         8.0  2022-01-02
# 2     Product_46  Region_3   20.43        12.0  2022-01-03
# 3     Product_36  Region_1   12.77        10.0  2022-01-04
# 4     Product_17  Region_6  125.69         6.0  2022-01-05
# ...          ...       ...     ...         ...         ...
# 1045  Product_45  Region_7   78.69         8.0  2022-07-28
# 1046   Product_1  Region_6     NaN         8.0  2022-08-02
# 1047  Product_17  Region_2  114.37        11.0  2023-12-18
# 1048         NaN  Region_8     NaN         5.0  2023-12-27
# 1049  Product_16  Region_2   69.30         8.0  2024-02-23
#
# [1050 rows x 5 columns]>

# %%
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   945.000000  946.000000        1050
# unique          50        10          NaN         NaN        1000
# top     Product_45  Region_9          NaN         NaN  2022-07-28
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.598688   10.048626         NaN
# std            NaN       NaN   124.020322    3.172261         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.430000    8.000000         NaN
# 50%            NaN       NaN    78.130000   10.000000         NaN
# 75%            NaN       NaN   142.570000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df.head(10)
# Out:
#       Product    Region   Price  Units Sold   Sale Date
# 0         NaN  Region_6   75.96        10.0  2022-01-01
# 1         NaN  Region_1  175.78         8.0  2022-01-02
# 2  Product_46  Region_3   20.43        12.0  2022-01-03
# 3  Product_36  Region_1   12.77        10.0  2022-01-04
# 4  Product_17  Region_6  125.69         6.0  2022-01-05
# 5  Product_45  Region_1    8.63        11.0  2022-01-06
# 6  Product_31  Region_3   23.73         6.0  2022-01-07
# 7  Product_18  Region_7   19.27         9.0  2022-01-08
# 8  Product_16  Region_9   30.70        14.0  2022-01-09
# 9   Product_9  Region_2  264.05         7.0  2022-01-10

# %%
df[df['Product'].isnull()  & df['Region'].isnull() & df['Price'].isnull() & df['Units Sold'].isnull() ]
# Out:
#     Product Region  Price  Units Sold   Sale Date
# 272     NaN    NaN    NaN         NaN  2022-09-30

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Price'].isnull()]
# Out:
#     Product Region  Price  Units Sold   Sale Date
# 272     NaN    NaN    NaN         NaN  2022-09-30

# %%
df[df['Price'].isnull()]
# Out:
#          Product    Region  Price  Units Sold   Sale Date
# 10    Product_20  Region_3    NaN         8.0  2022-01-11
# 12     Product_2  Region_3    NaN         6.0  2022-01-13
# 51    Product_17  Region_5    NaN        12.0  2022-02-21
# 59    Product_12  Region_8    NaN         7.0  2022-03-01
# 63    Product_33       NaN    NaN         6.0  2022-03-05
# ...          ...       ...    ...         ...         ...
# 1002  Product_13  Region_3    NaN         8.0  2022-04-05
# 1006  Product_41  Region_3    NaN        18.0  2023-01-26
# 1028  Product_42  Region_6    NaN         8.0  2024-01-19
# 1046   Product_1  Region_6    NaN         8.0  2022-08-02
# 1048         NaN  Region_8    NaN         5.0  2023-12-27
#
# [105 rows x 5 columns]

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Price'].isnull() & df['Units Sold'].isnull()]
# Out:
#     Product Region  Price  Units Sold   Sale Date
# 272     NaN    NaN    NaN         NaN  2022-09-30

# %%
df.drop([272], axis=0, inplace=True)

# %%
missing = df[df['Product'].isnull() & df['Region'].isnull()]
# Out:
#     Product Region   Price  Units Sold   Sale Date
# 18      NaN    NaN  276.27         9.0  2022-01-19
# 21      NaN    NaN   46.10        14.0  2022-01-22
# 57      NaN    NaN   30.71        12.0  2022-02-27
# 184     NaN    NaN  117.23         8.0  2022-07-04
# 203     NaN    NaN  134.49        13.0  2022-07-23
# 317     NaN    NaN   39.33        12.0  2022-11-14
# 629     NaN    NaN  151.72        11.0  2023-09-22
# 677     NaN    NaN  162.27         6.0  2023-11-09
# 786     NaN    NaN  249.05         6.0  2024-02-26

# %%
df.drop(df[df['Product'].isnull() & df['Region'].isnull()].index, axis=0 , inplace=True )

# %%
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   936.000000  937.000000        1040
# unique          50        10          NaN         NaN         990
# top     Product_45  Region_9          NaN         NaN  2022-05-17
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.343579   10.048026         NaN
# std            NaN       NaN   124.320943    3.175568         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.285000    8.000000         NaN
# 50%            NaN       NaN    77.520000   10.000000         NaN
# 75%            NaN       NaN   141.912500   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df_test= df.copy()

# %%
df_test.groupby('Region').describe()
# Out:
#            Price
#            count        mean         std   min      25%     50%       75%
# Region
# Region_1    77.0  102.055844  119.538086  0.96  26.0900  76.660  117.3300  \
# Region_10   98.0  101.472959   95.235575  5.48  33.8825  76.915  134.7500
# Region_2    76.0  125.228421  121.794759  0.58  29.2025  94.490  201.7300
# Region_3    82.0   97.719878   98.490504  1.29  26.8525  78.050  132.7475
# Region_4    88.0  106.825568  101.862712  0.20  31.3950  83.510  141.7850
# Region_5    83.0  110.395060  100.356902  0.31  38.9450  82.070  147.0250
# Region_6    81.0   81.150000   91.474345  0.54  27.9400  50.880   97.3000
# Region_7    70.0   92.043714   91.539662  0.61  23.9350  70.250  118.9775
# Region_8    85.0  156.836941  256.273082  0.61  37.7000  92.700  192.9100
# Region_9   106.0  103.798019   89.781121  0.33  30.3775  90.215  141.2050
#
#                    Units Sold
#                max      count       mean       std  min  25%   50%    75%
# Region
# Region_1    713.29       80.0  10.150000  3.460811  2.0  8.0  10.0  12.25  \
# Region_10   460.20       98.0  10.163265  2.895763  4.0  8.0  10.0  13.00
# Region_2    623.60       78.0   9.884615  3.353543  2.0  8.0  10.0  12.00
# Region_3    665.00       88.0  10.227273  3.479752  2.0  8.0  10.0  12.00
# Region_4    505.01       95.0   9.884211  3.367123  4.0  8.0   9.0  11.50
# Region_5    487.81       84.0  10.095238  3.236163  2.0  8.0  10.0  12.00
# Region_6    510.06       85.0  10.117647  3.021399  3.0  8.0  10.0  12.00
# Region_7    517.29       68.0   9.823529  3.190196  3.0  7.0   9.0  12.00
# Region_8   2143.30       83.0   9.819277  2.992448  4.0  7.0  10.0  12.00
# Region_9    496.61       97.0  10.195876  3.248843  3.0  8.0  10.0  12.00
#
#
#             max
# Region
# Region_1   18.0
# Region_10  16.0
# Region_2   18.0
# Region_3   19.0
# Region_4   22.0
# Region_5   20.0
# Region_6   18.0
# Region_7   19.0
# Region_8   19.0
# Region_9   17.0

# %%
df.drop(df[df['Product'].isnull() & df['Region'].isnull()].index, axis=0, inplace=True)

# %%
df_test['Region'] = df_test['Region'].fillna('Other')

# %%
df_test.groupby('Region').describe()
# Out:
#            Price
#            count        mean         std   min      25%     50%       75%
# Region
# Other       90.0  102.524111  101.996646  2.39  33.9050  66.880  149.8300  \
# Region_1    77.0  102.055844  119.538086  0.96  26.0900  76.660  117.3300
# Region_10   98.0  101.472959   95.235575  5.48  33.8825  76.915  134.7500
# Product_27   273.87       14.0  10.857143  3.134354  5.0   9.25  11.0  13.00
# Product_28   242.26       16.0  10.312500  4.045059  4.0   7.75   9.0  14.00
# Product_29   460.20       20.0   9.300000  2.494204  4.0   8.50   9.5  11.00
# Product_3    201.54       11.0  11.636364  4.249064  3.0   9.50  12.0  15.00
# Product_30   385.96       19.0  11.052632  2.527047  6.0   9.00  11.0  13.00
# Product_31   665.00       22.0   9.818182  3.064953  3.0   7.25  10.5  11.00
# Product_32   390.63       16.0   9.062500  3.108456  4.0   7.00   8.0  10.50
# Product_33   202.95       26.0   9.115385  2.747026  3.0   7.00   9.5  10.00
# Product_34   496.61       16.0  10.250000  2.768875  6.0   8.75  10.0  12.25
# Product_35   511.74       18.0   9.777778  4.138138  3.0   6.50  10.0  13.00
# Product_36   234.01       11.0   8.818182  2.227922  4.0   7.50   9.0  10.00
# Product_37   315.48       20.0   9.650000  2.539685  3.0   9.00  10.0  11.00
# Product_38   259.52       11.0   9.090909  1.300350  7.0   8.00   9.0  10.00
# Product_39   318.96       17.0   8.411765  2.237712  4.0   7.00   9.0  10.00
# Product_4    199.61       22.0  10.590909  3.187163  6.0   8.00  10.5  13.00
# Product_40   426.02       19.0   9.263158  2.959769  5.0   7.00   9.0  11.00
# Product_41   713.29       19.0  11.000000  4.136558  2.0   8.00  10.0  14.50
# Product_42   240.97       16.0   9.312500  3.458685  4.0   8.00   8.0  11.25
# Product_43   175.84       22.0  10.681818  2.901336  4.0   9.00  11.0  12.75
# Product_44   251.53       16.0   9.812500  3.885336  4.0   7.75   8.5  13.25
# Product_45   580.60       21.0   8.714286  2.452404  4.0   7.00   9.0  10.00
# Product_46   273.74       19.0   9.631579  2.671049  6.0   7.50  10.0  11.00
# Product_47   286.46       11.0   9.545455  3.012097  6.0   7.00   9.0  11.00
# Product_48   418.24       23.0  10.521739  2.677678  6.0   8.50  10.0  13.00
# Product_49   329.37       13.0   9.769231  2.127355  7.0   8.00  10.0  11.00
# Product_5    264.72       22.0   9.090909  4.230379  2.0   7.00   9.0  11.00
# Product_50   447.75       19.0  11.631579  3.774336  7.0   9.00  11.0  14.00
# Product_6    299.38       16.0   9.125000  4.193249  2.0   5.75   9.0  12.00
# Product_7    605.87       16.0  11.062500  2.862837  6.0  10.00  10.0  12.00
# Product_8    352.86       14.0  10.714286  2.672612  7.0   9.00  10.5  12.00
# Product_9    264.05       13.0  11.000000  3.511885  6.0   9.00  10.0  14.00
#
#
#              max
# Product
# Other       16.0
# Product_1   16.0
# Product_10  17.0
# Product_11  14.0
# Product_12  16.0
# Product_13  19.0
# Product_14  19.0
# Product_15  14.0
# Product_16  18.0
# Product_17  15.0
# Product_18  14.0
# Product_19  15.0
# Product_2   17.0
# Product_20  17.0
# Product_21  17.0
# Product_22  19.0
# Product_23  15.0
# Product_24  16.0
# Product_25  16.0
# Product_26  14.0
# Product_27  16.0
# Product_28  18.0
# Product_29  13.0
# Product_3   17.0
# Product_30  16.0
# Product_31  17.0
# Product_32  15.0
# Product_33  15.0
# Product_34  15.0
# Product_35  16.0
# Product_36  12.0
# Product_37  14.0
# Product_38  11.0
# Product_39  13.0
# Product_4   16.0
# Product_40  17.0
# Product_41  18.0
# Product_42  18.0
# Product_43  16.0
# Product_44  17.0
# Product_45  14.0
# Product_46  15.0
# Product_47  15.0
# Product_48  15.0
# Product_49  13.0
# Product_5   20.0
# Product_50  22.0
# Product_6   16.0
# Product_7   17.0
# Product_8   17.0
# Product_9   18.0

# %%
df_test_2.groupby('Product').describe().loc['Product_4']
# Out:
# Price       count     19.000000
#             mean      83.006842
#             std       60.188802
#             min        2.520000
#             25%       24.175000
#             50%       85.840000
#             75%      123.890000
#             max      199.610000
# Units Sold  count     22.000000
#             mean      10.590909
#             std        3.187163
#             min        6.000000
#             25%        8.000000
#             50%       10.500000
#             75%       13.000000
#             max       16.000000
# Name: Product_4, dtype: float64

# %%
df.dropna(subset=['Product'],axis=0 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       854 non-null    float64
#  3   Units Sold  852 non-null    float64
#  4   Sale Date   947 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.4+ KB

# %%
df_test = df.copy()
df_test_2 = df.copy()
df_test_3 = df.copy()

# %%
df_test['Price'] = df['Price'].fillna(df_test['Price'].median())

# %%
df_test['Price'] = df_test['Price'].fillna(df['Price'].median())

# %%
df_test_2['Price'] = df['Price'].fillna(df_test_2.groupby('Product') ['Price'].transform('median'))

# %%
df_test_2['Units Sold'] = df_test_2['Product'].fillna(df_test_2.groupby('Product')['Units Sold'].transform('median'))

# %%
df['Units Sold'] = df['Units Sold'].fillna(df.groupby('Product')['Units Sold'].transform('median'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       854 non-null    float64
#  3   Units Sold  947 non-null    float64
#  4   Sale Date   947 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.4+ KB

# %%
df['Price'] = df['Price'].fillna(df.groupby('Product') ['Price'].transform('median'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       947 non-null    float64
#  3   Units Sold  947 non-null    float64
#  4   Sale Date   947 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.4+ KB

# %%
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       947   947.000000  947.000000         947
# unique          50        11          NaN         NaN         900
# top     Product_45  Region_9          NaN         NaN  2023-04-15
# freq            28       101          NaN         NaN           2
# mean           NaN       NaN   105.009050   10.056494         NaN
# std            NaN       NaN   121.081348    3.045675         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    33.820000    8.000000         NaN
# 50%            NaN       NaN    78.600000   10.000000         NaN
# 75%            NaN       NaN   133.250000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, y='Price')
# Out:
# <Axes: ylabel='Price'>

# %%
price_drop_outlier= df[df['Price']>1000].index
price_drop_outlier
# Out:
# Index([969], dtype='int64')

# %%
df.drop(price_drop_outlier, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     946 non-null    object
#  1   Region      946 non-null    object
#  2   Price       946 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   946 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.3+ KB

# %%
sns.boxplot(data = df, y = 'Units Sold')
# Out:
# <Axes: ylabel='Units Sold'>

# %%
df['Units Sold'].sort_values(ascending=False).head(10)
# Out:
# 719     22.0
# 221     20.0
# 232     19.0
# 962     19.0
# 912     19.0
# 167     18.0
# 796     18.0
# 678     18.0
# 1006    18.0
# 390     18.0
# Name: Units Sold, dtype: float64

# %%
Sales_Unit_outliers=df[df['Units Sold'] >=19].index

# %%
Sales_Unit_outliers
# Out:
# Index([221, 232, 719, 912, 962], dtype='int64')

# %%
df.drop(Sales_Unit_outliers, inplace=True)

# %%
df['Units Sold'].isnull().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 894 entries, 2 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     894 non-null    object
#  1   Region      894 non-null    object
#  2   Price       894 non-null    float64
#  3   Units Sold  894 non-null    float64
#  4   Sale Date   894 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 41.9+ KB

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
from scipy import stats

# %%
print(stats.skew(df['Price']))
# Out:
# 2.1839200184672505

# %%
sns.histplot(df['Units Sold'])
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %%
print(stats.skew(df['Units Sold']))
print(stats.kurtosis(df['Units Sold']))
# Out:
# 0.1439472082451089
# 0.04683483180660897

# %%
df.groupby('Product')['Units Sold'].count().sort_values(ascending=False).plot(kind='bar' ,figsize= (10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Region')['Price'].count().sort_values(ascending= False).plot(kind='bar', fig=(10,5))
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region = df.groupby('Region')['Units Sold'].aggregate(['sum', 'mean', 'median', 'count'])
units_by_region
# Out:
#              sum       mean  median  count
# Region
# Other      901.5  10.016667    10.0     90
# Region_1   745.0  10.205479    10.0     73
# Region_10  901.5  10.016667    10.0     90
# Region_2   720.5  10.147887    10.0     71
# Region_3   786.5  10.083333    10.0     78
# Region_4   881.5   9.686813     9.5     91
# Region_5   833.5  10.042169    10.0     83
# Region_6   769.0  10.118421    10.0     76
# Region_7   618.0   9.809524     9.0     63
# Region_8   825.0   9.939759    10.0     83
# Region_9   975.0  10.156250     9.5     96

# %%
units_by_region['sum'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region['mean'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
print(stats.skew(df['Price']))
# Out:
# 2.1839200184672505

# %%
sns.histplot(df['Units Sold'])
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %%
print(stats.skew(df['Units Sold']))
print(stats.kurtosis(df['Units Sold']))
# Out:
# 0.1439472082451089
# 0.04683483180660897

# %%
df.groupby('Product')['Units Sold'].count().sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Region')['Units Sold'].count().sort_values(ascending=False).plot(kind='bar', fig=(10,5))
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby('Region')['Price'].count().sort_values(ascending=False).plot(kind='bar', fig=(10,5))
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region = df.groupby('Region')['Units Sold'].aggregate(['sum','mean','median','count'])

# %%
units_by_region
# Out:
#              sum       mean  median  count
# Region
# Other      901.5  10.016667    10.0     90
# Region_1   745.0  10.205479    10.0     73
# Region_10  901.5  10.016667    10.0     90
# Region_2   720.5  10.147887    10.0     71
# Region_3   786.5  10.083333    10.0     78
# Region_4   881.5   9.686813     9.5     91
# Region_5   833.5  10.042169    10.0     83
# Region_6   769.0  10.118421    10.0     76
# Region_7   618.0   9.809524     9.0     63
# Region_8   825.0   9.939759    10.0     83
# Region_9   975.0  10.156250     9.5     96

# %%
units_by_region['sum'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region['mean'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_product = df.groupby('Price')['Units Sold'].aggregate(['sum','mean','median', 'count'])

# %%
units_by_product['sum'].sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Price'>

# %%
units_by_product = df.groupby('Product')['Units Sold'].aggregate(['sum','mean','median','count'])

# %%
units_by_product.head()
# Out:
#               sum       mean  median  count
# Product
# Product_1   237.0   9.875000    9.00     24
# Product_10  180.5  11.281250   11.25     16
# Product_11  159.0  11.357143   11.50     14
# Product_12  139.0  10.692308   11.00     13
# Product_13  234.0  10.173913   10.00     23

# %%
units_by_product['sum'].sort_values(ascending=False).plot(kind='bar' , figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
units_by_product['mean'].sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Product')['Price'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Product')['Price'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
sns.lmplot(data=df, x='Price', y='Units Sold')

# %%
df['Revenue']= df['Price']* df['Units Sold']

# %%
region_1 = df[df['Region']=='Region_1'].groupby('Product').aggregate({'Price':'mean','Units Sold':['sum','mean'],'Revenue':['sum','mean']})

# %%
region_1 = df[df['Region']=='Region_1'].groupby('Product').aggregate({'Price':'mean','Units Sold':['sum','mean'],'Revenue':['sum','mean']})

# %%
region_1['Price'].sort_values('mean',ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_1 = df[df['Region']=='Region_1'].groupby('Product').aggregate({'Price':'mean', 'Units Sold': ['sum','mean'], 'Revenue': ['sum','mean']})

# %%
region_1['Price'].sort_values('mean',ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_1['Revenue'].sort_values('mean', ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_1['Price'].sort_values('mean', ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>
