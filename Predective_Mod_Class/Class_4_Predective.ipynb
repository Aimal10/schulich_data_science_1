# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import statsmodels.api as sum
from sklearn import linear_model as linear_model

# %%
x_1 = np.random.uniform(10,40,100)
x_2 = np.random.uniform(-50,20,100)
x_3 = np.random.uniform(20,60,100)
x_4 = np.random.uniform(10,40,100)
x_5 = np.random.uniform(-50,20,100)
x_6 = np.random.uniform(20,60,100)
epsilon = np.random.normal(0,10,100)

# %%
y=-30+1.3*x_1+1.6*x_2+1.1*x_3+0.7*x_4-2.1*x_5-0.9*x_6+epsilon

# %%
X_ols=pd.DataFrame()
X_ols['Constant']=pd.Series(np.ones(100))
X_ols['X1'] = pd.Series(x_1)
X_ols['X2'] = pd.Series(x_2)
X_ols['X3'] = pd.Series(x_3)
X_ols['X4'] = pd.Series(x_4)
X_ols['X5'] = pd.Series(x_5)
X_ols['X6'] = pd.Series(x_6)

# %%
import statsmodels.api as sm

# %%
model_reg = sm.OLS(y,X_ols).fit()
model_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     698.1
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):           5.11e-75
# Time:                        19:44:17   Log-Likelihood:                -356.26
# No. Observations:                 100   AIC:                             726.5
# Df Residuals:                      93   BIC:                             744.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Constant     -23.1432      6.200     -3.733      0.000     -35.455     -10.831
# X1             1.3661      0.100     13.641      0.000       1.167       1.565
# X2             1.5809      0.045     35.396      0.000       1.492       1.670
# X3             1.0271      0.077     13.426      0.000       0.875       1.179
# X4             0.9056      0.109      8.327      0.000       0.690       1.122
# X5            -2.1163      0.045    -47.536      0.000      -2.205      -2.028
# X6            -1.1695      0.080    -14.666      0.000      -1.328      -1.011
# ==============================================================================
# Omnibus:                        0.293   Durbin-Watson:                   1.597
# Prob(Omnibus):                  0.864   Jarque-Bera (JB):                0.058
# Skew:                           0.037   Prob(JB):                        0.972
# Kurtosis:                       3.092   Cond. No.                         491.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Now we add some unrelated coefficients
x_7 = np.random.uniform(10,40,100)
x_8 = np.random.uniform(-50,20,100)
x_9 = np.random.uniform(20,60,100)
x_10 = np.random.uniform(10,40,100)
x_11 = np.random.uniform(-50,20,100)
x_12 = np.random.uniform(20,60,100)

# %%
X_ext = pd.DataFrame()
X_ext['Constant']=pd.Series(np.ones(100))
X_ext['X1'] = pd.Series(x_1)
X_ext['X2'] = pd.Series(x_2)
X_ext['X3'] = pd.Series(x_3)
X_ext['X4'] = pd.Series(x_4)
X_ext['X5'] = pd.Series(x_5)
X_ext['X6'] = pd.Series(x_6)
X_ext['X7'] = pd.Series(x_7)
X_ext['X8'] = pd.Series(x_8)
X_ext['X9'] = pd.Series(x_9)
X_ext['X10'] = pd.Series(x_10)
X_ext['X11'] = pd.Series(x_11)
X_ext['X12'] = pd.Series(x_12)

# %%
model_reg = sm.OLS(y,X_ext).fit()
model_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     374.8
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):           2.08e-69
# Time:                        19:44:43   Log-Likelihood:                -349.50
# No. Observations:                 100   AIC:                             725.0
# Df Residuals:                      87   BIC:                             758.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Constant     -28.6088      8.589     -3.331      0.001     -45.679     -11.538
# X1             1.3948      0.101     13.852      0.000       1.195       1.595
# X2             1.5746      0.045     34.649      0.000       1.484       1.665
# X3             1.0196      0.075     13.556      0.000       0.870       1.169
# X4             0.9642      0.107      9.032      0.000       0.752       1.176
# X5            -2.1429      0.044    -48.681      0.000      -2.230      -2.055
# X6            -1.1466      0.079    -14.599      0.000      -1.303      -0.991
# X7             0.2629      0.108      2.445      0.017       0.049       0.477
# X8            -0.0041      0.048     -0.086      0.932      -0.099       0.091
# X9            -0.0231      0.080     -0.287      0.775      -0.183       0.137
# X10           -0.0975      0.101     -0.968      0.336      -0.298       0.103
# X11            0.0830      0.046      1.787      0.077      -0.009       0.175
# X12           -0.0058      0.083     -0.070      0.944      -0.171       0.159
# ==============================================================================
# Omnibus:                        0.682   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.711   Jarque-Bera (JB):                0.270
# Skew:                           0.039   Prob(JB):                        0.874
# Kurtosis:                       3.242   Cond. No.                         987.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_1 = np.random.uniform(10,40,100)
y_2 = np.random.uniform(-50,20,100)
y_3 = np.random.uniform(20,60,100)
y_4 = np.random.uniform(50,40,100)
y_5 = np.random.uniform(-60,20,100)
y_6 = np.random.uniform(20,60,100)
epsilon = np.random.normal(0,10,100)

# %%
y=-30+1.3*x_1+1.8*x_2+1.1*x_3+0.9*x_4-2.1*x_5-0.9*x_6+epsilon

# %%
X_ols=pd.DataFrame()
X_ols['Constant']=pd.Series(np.ones(100))
X_ols['X1'] = pd.Series(y_1)
X_ols['X2'] = pd.Series(y_2)
X_ols['X3'] = pd.Series(y_3)
X_ols['X4'] = pd.Series(y_4)
X_ols['X5'] = pd.Series(y_5)
X_ols['X6'] = pd.Series(y_6)

# %%
model_reg = sm.OLS(y,X_ols).fit()
model_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.045
# Method:                 Least Squares   F-statistic:                    0.2968
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):              0.937
# Time:                        19:47:11   Log-Likelihood:                -549.77
# No. Observations:                 100   AIC:                             1114.
# Df Residuals:                      93   BIC:                             1132.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Constant      54.9934    116.738      0.471      0.639    -176.825     286.812
# X1            -0.3496      0.765     -0.457      0.649      -1.869       1.170
# X2             0.2378      0.316      0.752      0.454      -0.390       0.866
# X3            -0.0474      0.552     -0.086      0.932      -1.143       1.048
# X4             0.2971      2.423      0.123      0.903      -4.515       5.110
# X5             0.2798      0.264      1.058      0.293      -0.245       0.805
# X6            -0.0497      0.511     -0.097      0.923      -1.065       0.966
# ==============================================================================
# Omnibus:                        4.336   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                2.677
# Skew:                          -0.196   Prob(JB):                        0.262
# Kurtosis:                       2.301   Cond. No.                     1.53e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Now we add some unrelated coefficients
y_7 = np.random.uniform(10,40,100)
y_8 = np.random.uniform(-50,20,100)
y_9 = np.random.uniform(20,60,100)
y_10 = np.random.uniform(10,40,100)
y_11 = np.random.uniform(-50,20,100)
y_12 = np.random.uniform(20,60,100)

# %%
X_ext = pd.DataFrame()
X_ext['Constant']=pd.Series(np.ones(100))
X_ext['X1'] = pd.Series(y_1)
X_ext['X2'] = pd.Series(y_2)
X_ext['X3'] = pd.Series(y_3)
X_ext['X4'] = pd.Series(y_4)
X_ext['X5'] = pd.Series(y_5)
X_ext['X6'] = pd.Series(y_6)
X_ext['X7'] = pd.Series(y_7)
X_ext['X8'] = pd.Series(y_8)
X_ext['X9'] = pd.Series(y_9)
X_ext['X10'] = pd.Series(y_10)
X_ext['X11'] = pd.Series(y_11)
X_ext['X12'] = pd.Series(y_12)

# %%
model_reg = sm.OLS(y,X_ext).fit()
model_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.043
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):              0.418
# Time:                        19:49:35   Log-Likelihood:                -544.00
# No. Observations:                 100   AIC:                             1114.
# Df Residuals:                      87   BIC:                             1148.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Constant     135.9718    124.101      1.096      0.276    -110.692     382.635
# X1            -0.6081      0.779     -0.781      0.437      -2.156       0.939
# X2             0.1749      0.317      0.553      0.582      -0.454       0.804
# X3             0.3394      0.558      0.608      0.545      -0.770       1.449
# X4            -0.5607      2.392     -0.234      0.815      -5.314       4.193
# X5             0.3530      0.263      1.340      0.184      -0.171       0.877
# X6            -0.2837      0.534     -0.531      0.596      -1.345       0.777
# X7            -0.6559      0.747     -0.878      0.383      -2.141       0.830
# X8            -0.3296      0.310     -1.064      0.290      -0.945       0.286
# X9            -0.1163      0.541     -0.215      0.830      -1.191       0.959
# X10           -1.4640      0.704     -2.079      0.041      -2.863      -0.065
# X11            0.5025      0.294      1.712      0.091      -0.081       1.086
# X12            0.4734      0.566      0.836      0.405      -0.652       1.599
# ==============================================================================
# Omnibus:                        2.645   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.266   Jarque-Bera (JB):                1.817
# Skew:                          -0.115   Prob(JB):                        0.403
# Kurtosis:                       2.381   Cond. No.                     2.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn import linear_model as lm

# %%
# When we input the matrix, we don't need to add the column of ones because \
# Lasso automatically takes it into account

X_ext = X_ext.drop(columns=['Constant'])
model_lasso = lm.Lasso(alpha=1).fit(X_ext,y)
model_lasso.coef_
# Out:
# array([-0.58385556,  0.16720225,  0.32327233, -0.38364239,  0.34817708,
#        -0.26743815, -0.63651162, -0.32424815, -0.111236  , -1.44707624,
#         0.49753346,  0.46587546])

# %%
model_lasso = lm.Lasso(alpha=10).fit(X_ext,y)
model_lasso.coef_
# Out:
# array([-0.38960181,  0.13600985,  0.18504481, -0.        ,  0.31060155,
#        -0.13996761, -0.45799819, -0.29216994, -0.05926673, -1.3137606 ,
#         0.46638779,  0.39454104])
