# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import sklearn as sl
import scipy as sp
import seaborn as sb
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
min(year_list)
# Out:
# 1994

# %%
max(year_list)
# Out:
# 2013

# %%
len(year_list)
# Out:
# 20

# %%
sum(year_list)
# Out:
# 40070

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
plt.figure(figsize=(24,16), dpi=40)
plt.plot(year_list,josb_assets_list, label = "Joseph A Bank", linewidth = 8)
plt.plot(year_list,mw_assets_list, 'r--', label = "Men's warehouse", linewidth=8)
xticks_location =np.arange(1994,2013,4)
plt.xticks(ticks=xticks_location, rotation=0, fontsize=50,horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95), fontsize= 50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize=50)
plt.ylabel('Total assets', fontsize= 65)
# Out:
# Text(0, 0.5, 'Total assets')

# %%
random_values=np.random.normal(1000,200,10000)
bins=np.linspace(400,1600,30)
plt.figure(figsize=(24,16), dpi=40)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize=65)
plt.ylabel('Frequency', fontsize=65)
plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.title('Histogram of Total assets Value', fontsize=50)
# Out:
# Text(0.5, 1.0, 'Histogram of Total assets Value')

# %%
list_vec= [0,1,2,3,4]

# %%
list_vec.append (5)

# %%
list_vec
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import numpy as np

# %%
array_vec= np.array([0,1,2,3,4])
array_vec[1]
# Out:
# 1

# %%
matrix_example= np.array([[1,2,3], [0,-1,2], [1,0,4]])
array_example= np.array([1,-2,1])

# %%
np.dot(matrix_example,array_example)
# Out:
# array([0, 4, 5])

# %%
np.linalg.inv(matrix_example)
# Out:
# array([[-1.33333333, -2.66666667,  2.33333333],
#        [ 0.66666667,  0.33333333, -0.66666667],
#        [ 0.33333333,  0.66666667, -0.33333333]])

# %%
np.transpose(matrix_example)
#In transpose matrix we replace rows with the columns
# Out:
# array([[ 1,  0,  1],
#        [ 2, -1,  0],
#        [ 3,  2,  4]])

# %%
np.linalg.eigvals(matrix_example)
# Out:
# array([ 4.93394491+0.j        , -0.46697245+0.62447535j,
#        -0.46697245-0.62447535j])

# %%
np.linalg.matrix_rank(matrix_example)

#inverse only applies to rank 3 means 3*3
# Out:
# 3

# %%
matrix_example
# Out:
# array([[ 1,  2,  3],
#        [ 0, -1,  2],
#        [ 1,  0,  4]])

# %%
matrix_example[0]
# Out:
# array([1, 2, 3])

# %%
matrix_example[1]
# Out:
# array([ 0, -1,  2])

# %%
matrix_example[-1]
# Out:
# array([1, 0, 4])

# %%
matrix_example[1][1]
# Out:
# -1

# %%
np.random.normal(10,2,[10,3])
# Out:
# array([[ 7.51126994, 12.44229957,  8.42315393],
#        [ 8.75138593, 10.05627943, 10.33479046],
#        [11.84754615, 10.81102739, 12.06117957],
#        [11.37216984,  9.76919364,  8.24594545],
#        [ 9.68841802, 13.64517527,  8.73005988],
#        [ 8.03294978,  8.1145664 ,  9.01923043],
#        [ 8.06405722, 10.2015639 ,  9.34051931],
#        [ 8.33491972,  9.3196183 ,  9.48899279],
#        [ 9.8116168 ,  9.01833991, 12.79521095],
#        [ 9.15047453,  8.85839849,  7.18555462]])

# %%
import scipy as sp

# %%
sp.stats.norm.pdf(14,10,2)

# probability density function (PDF) of a normal distribution at a specific value.

#Here's what each argument means:

#14 is the value at which you want to calculate the PDF.
#10 is the mean (average) of the normal distribution.
#2 is the standard deviation of the normal distribution.
# Out:
# 0.02699548325659403

# %%
sp.stats.norm.cdf(14,10,2)

#calculate the cumulative distribution function (CDF) of a normal distribution at a specific value.

#Here's what each argument means:

#14 is the value for which you want to calculate the CDF.
#10 is the mean (average) of the normal distribution.
#2 is the standard deviation of the normal distribution.
# Out:
# 0.9772498680518208

# %%
sp.stats.norm.cdf(40000,10000,2)
# Out:
# 1.0

# %%
sp.stats.norm.isf(0.05,40000,10000)
# Out:
# 56448.53626951473

# %%
sp.stats.norm.isf(1-0.9772498680518208,10,2)

# function to calculate the inverse survival function (also known as the quantile function) of a normal distribution.

#Here's what each argument means:

#1 - 0.9772498680518208: This is the survival probability. It's the complement of the cumulative probability. In other words, you're looking for a value such that there is only a 2.275% chance (100% - 97.725%) of exceeding it in a normal distribution.

#10 is the mean (average) of the normal distribution.

#2 is the standard deviation of the normal distribution.
# Out:
# 14.0

# %%
sp.stats.norm.cdf(2,0,1)
# Out:
# 0.9772498680518208

# %%
sp.stats.norm.isf(1-0.9772498680518208,0,1)*2+10
# Out:
# 14.0

# %%
pd.Series(np.random.normal(10,2,8))
# Out:
# 0    11.975623
# 1     9.823805
# 2     7.881076
# 3    13.114827
# 4    13.836744
# 5    11.354041
# 6    10.436787
# 7     9.397234
# dtype: float64

# %%
DataTable= pd.DataFrame(np.random.normal(10,2,[8,3]), columns=list(["Column 1", "Column 2", "Column 3"]))

# %%
DataTable
# Out:
#    Column 1   Column 2   Column 3
# 0  9.135112  10.718625   6.839677
# 1  7.829935  10.908893  10.982682
# 2  9.692445  11.248954   9.307112
# 3  9.755448  11.372189   7.870235
# 4  7.523046  11.190402   9.204239
# 5  7.158957  11.118606   7.010443
# 6  9.625638  11.055247  13.379576
# 7  9.514782   8.940331  11.977261

# %%
DataTable[DataTable["Column 1"]>13]
# Out:
# Empty DataFrame
# Columns: [Column 1, Column 2, Column 3]
# Index: []

# %%
input_table= pd.read_csv('/Users/aimaldastagirzada/Downloads/sales_data (1).csv')

# %%
input_table.head()
# Out:
#     Order ID  Product ID  Amount (kg) Order Confirm Date
# 0  1005781.0   8908023.0      20000.0                NaN  \
# 1  1005998.0   8909373.0       6297.0                NaN
# 2  1005969.0   8908023.0      20000.0         2020-05-29
# 3  1005969.0   8908023.0      20000.0         2020-05-29
# 4        NaN         NaN          NaN                NaN
#
#   Required Delivery Date
# 0             2020-07-30
# 1             2020-07-15
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
input_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1928 entries, 0 to 1927
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1927 non-null   float64
#  1   Product ID              1927 non-null   float64
#  2   Amount (kg)             1927 non-null   float64
#  3   Order Confirm Date      1925 non-null   object
#  4   Required Delivery Date  1925 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 75.4+ KB

# %%
input_table_imputted_partially= input_table.dropna(subset=["Order Confirm Date"])
input_table_imputted_fully =input_table.dropna()
input_table_imputted_fully
# Out:
#        Order ID  Product ID  Amount (kg) Order Confirm Date
# 5     1006069.0   8902635.0      10000.0         2020-06-16  \
# 6     1005998.0   8909373.0       6500.0         2020-06-30
# 7     1006067.0   8908023.0      21000.0         2020-06-22
# 8     1006067.0   8908023.0      21000.0         2020-06-22
# 9     1006067.0   8908023.0      10000.0         2020-06-22
# ...         ...         ...          ...                ...
# 1923  1006010.0   8909286.0        800.0         2019-12-10
# 1924  1006020.0   8908023.0      20000.0         2019-12-11
# 1925  1006020.0   8908023.0       9000.0         2020-01-14
# 1926  1005495.0   8908112.0      14400.0         2019-07-08
# 1927  1005516.0   8905735.0       1877.0         2019-07-08
#
#      Required Delivery Date
# 5                2020-08-05
# 6                2020-09-10
# 7                2020-07-07
# 8                2020-07-14
# 9                2020-07-20
# ...                     ...
# 1923             2020-01-10
# ...

# %%
input_table_imputted_fully.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1923 entries, 5 to 1927
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                1923 non-null   float64
#  1   Product ID              1923 non-null   float64
#  2   Amount (kg)             1923 non-null   float64
#  3   Order Confirm Date      1923 non-null   object
#  4   Required Delivery Date  1923 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 90.1+ KB

# %%
df=pd.read_csv('/Users/aimaldastagirzada/Downloads/small_dataset.csv')

# %%
df
# Out:
#     Transaction ID             ItemsPurchased
# 0                1         biscuit,bread,milk
# 1                2  biscuit,bread,cereal,milk
# 2                3                  bread,tea
# 3                4             bread,jam,milk
# 4                5                biscuit,tea
# 5                6                  bread,tea
# 6                7                 cereal,tea
# 7                8          biscuit,bread,tea
# 8                9              bread,jam,tea
# 9               10                 bread,milk
# 10              11             biscuit,cereal
# 11              12     biscuit,bread,milk,tea
# 12              13                  bread,tea
# 13              14             bread,jam,milk
# 14              15                biscuit,tea
# 15              16                  bread,tea
# 16              17                 cereal,tea
# 17              18                  bread,tea
# 18              19              bread,jam,tea
# ...

# %%
transcation_list=list(df["ItemsPurchased"].apply(lambda t:t.split(",")))
encoder =Tran
# Out:
# [['biscuit', 'bread', 'milk'],
#  ['biscuit', 'bread', 'cereal', 'milk'],
#  ['bread', 'tea'],
#  ['bread', 'jam', 'milk'],
#  ['biscuit', 'tea'],
#  ['bread', 'tea'],
#  ['cereal', 'tea'],
#  ['biscuit', 'bread', 'tea'],
#  ['bread', 'jam', 'tea'],
#  ['bread', 'milk'],
#  ['biscuit', 'cereal'],
#  ['biscuit', 'bread', 'milk', 'tea'],
#  ['bread', 'tea'],
#  ['bread', 'jam', 'milk'],
#  ['biscuit', 'tea'],
#  ['bread', 'tea'],
#  ['cereal', 'tea'],
#  ['bread', 'tea'],
#  ['bread', 'jam', 'tea'],
#  ['bread', 'milk']]
