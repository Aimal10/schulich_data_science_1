# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/aimaldastagirzada/Downloads/sales_data (2).csv')

# %%
df
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_1   72.87        10.0  2022-01-01
# 1     Product_40  Region_2   46.19        10.0  2022-01-02
# 2      Product_1  Region_5     NaN         4.0  2022-01-03
# 3      Product_6  Region_8  143.47         8.0  2022-01-04
# 4     Product_44  Region_4  122.54        10.0  2022-01-05
# ...          ...       ...     ...         ...         ...
# 1045  Product_42  Region_3   18.63         9.0  2023-07-10
# 1046   Product_4  Region_3  159.27        10.0  2024-07-14
# 1047  Product_43  Region_1    2.91        13.0  2023-08-17
# 1048  Product_27  Region_7    1.96         8.0  2024-03-10
# 1049   Product_3       NaN  302.68        11.0  2023-09-09
#
# [1050 rows x 5 columns]

# %%
df.head()
# Out:
#       Product    Region   Price  Units Sold   Sale Date
# 0         NaN  Region_1   72.87        10.0  2022-01-01
# 1  Product_40  Region_2   46.19        10.0  2022-01-02
# 2   Product_1  Region_5     NaN         4.0  2022-01-03
# 3   Product_6  Region_8  143.47         8.0  2022-01-04
# 4  Product_44  Region_4  122.54        10.0  2022-01-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      942 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  943 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
df.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold   Sale Date
# count         947       942   945.000000  943.000000        1050
# unique         50        10          NaN         NaN        1000
# top     Product_4  Region_5          NaN         NaN  2023-07-31
# freq           30       112          NaN         NaN           2
# mean          NaN       NaN   108.628011   10.200424         NaN
# std           NaN       NaN   167.350086    3.247589         NaN
# min           NaN       NaN     0.190000    2.000000         NaN
# 25%           NaN       NaN    26.420000    8.000000         NaN
# 50%           NaN       NaN    64.640000   10.000000         NaN
# 75%           NaN       NaN   142.310000   12.000000         NaN
# max           NaN       NaN  2636.900000   22.000000         NaN

# %%
df['Sale Date'] = pd.to_datetime(df['Sale Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      942 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  943 non-null    float64
#  4   Sale Date   1050 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 41.1+ KB

# %%
df[df['Product'].isnull () & df['Price'].isnull () & df['Region'].isnull () & df['Units Sold'].isnull () & df['Sale Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Product, Region, Price, Units Sold, Sale Date]
# Index: []

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Price'].isnull()]
# Out:
#   Product Region  Price  Units Sold  Sale Date
# 7     NaN    NaN    NaN        11.0 2022-01-08

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Units Sold'].isnull()]
# Out:
#    Product Region  Price  Units Sold  Sale Date
# 22     NaN    NaN  36.26         NaN 2022-01-23

# %%
df.drop([7,22], axis=0, inplace=True)

# %%
df[df['Product'].isnull() & df['Region'].isnull()]
# Out:
#      Product Region   Price  Units Sold  Sale Date
# 43       NaN    NaN   13.59        12.0 2022-02-13
# 228      NaN    NaN   24.35        10.0 2022-08-17
# 304      NaN    NaN    9.43         7.0 2022-11-01
# 318      NaN    NaN  305.21         9.0 2022-11-15
# 362      NaN    NaN  292.85         9.0 2022-12-29
# 604      NaN    NaN   49.04        13.0 2023-08-28
# 706      NaN    NaN  184.50         6.0 2023-12-08
# 842      NaN    NaN  200.61        12.0 2024-04-22
# 1006     NaN    NaN  292.85         9.0 2022-12-29
# 1016     NaN    NaN  200.61        12.0 2024-04-22

# %%
df.drop(df[df['Product'].isnull () & df['Region'].isnull()].index, axis=0, inplace=True)

# %%
df.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       942   934.000000  932.000000  \
# unique         50        10          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       112          NaN         NaN
# mean          NaN       NaN   108.184336   10.202790
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    26.442500    8.000000
# 50%           NaN       NaN    64.620000   10.000000
# 75%           NaN       NaN   141.150000   12.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   167.810334    3.258414
#
#                             Sale Date
# count                            1038
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-15 23:01:44.046242816
# min               2022-01-01 00:00:00
# 25%               2022-09-08 06:00:00
# ...

# %% [markdown]
# ## Imputation

# %% [markdown]
# ## Region by Region_5

# %%
df_test_r =df.copy()

# %%
df_test_r['Region'] = df['Region'].fillna('Region_5')

# %%
df_test_r.groupby('Region').describe()
# Out:
#            Price
#            count        mean   min      25%     50%       75%      max
# Region
# Region_1    78.0   97.792821  2.91  40.7575  72.440  121.2150   469.65  \
# Region_10   80.0  113.310500  0.19  26.7425  67.900  151.6175   650.50
# Region_2    94.0  137.287340  1.49  24.4725  66.960  158.7025  2636.90
# Region_3    75.0   91.008400  3.40  35.1000  58.370  121.1550   485.84
# Region_4    79.0   85.824051  2.37  21.3050  47.340  119.8500   489.40
# Region_5   187.0  117.270160  0.27  26.8850  68.150  151.5300  2544.60
# Region_6    81.0   96.727037  0.71  28.7300  55.410  125.5100   417.05
# Region_7    84.0  107.210119  0.19  20.1225  58.865  123.8175  1793.90
# Region_8    88.0  120.850909  0.27  38.8225  81.585  145.4825  1296.00
# Region_9    88.0   95.861477  0.25  23.6950  66.375  134.7675   531.91
#
#                       Units Sold             ...                 Sale Date
#                   std      count       mean  ...   max       std     count
# ...

# %%
df['Region']= df['Region'].fillna('Other')

# %%
df_test_pro= df.copy()

# %%
df_test_pro['Product'] = df_test_pro['Product'].fillna('Other')
df_test_r ['Product'] = df_test_r['Product'].fillna('Product_4')

# %%
df_test_r.groupby('Product').describe()
# Out:
#             Price
#             count        mean    min      25%      50%       75%      max
# Product
# Product_1    19.0   99.960526   3.40  46.8550   75.880  107.4200   441.99  \
# Product_10   17.0   97.610588   3.63  36.2400   85.330  121.6500   258.01
# Product_11   12.0  120.550833  21.70  61.6225   78.720  142.3325   333.79
# Product_12   14.0   77.138571   2.37  30.6700   62.570  108.5425   207.17
# Product_13   17.0   88.629412  12.86  18.2100   54.910  145.8400   274.59
# Product_14   10.0   95.544000   4.15  17.6350   40.905  102.9875   469.65
# Product_15   19.0   89.121053   5.71  24.2300   39.720  140.4600   409.83
# Product_16   13.0   77.116154   4.52  11.2800   46.950   91.9800   395.76
# Product_17   21.0  127.157143   5.39  54.6500  120.080  180.6100   284.74
# Product_18   11.0  107.107273   1.90  18.7450   97.780  139.1000   417.05
# Product_19   20.0  115.748500  16.82  46.6175   96.925  158.4750   308.76
# ...

# %%
df_test_pro.groupby('Product').describe()
# Out:
#            Price
#            count        mean    min      25%      50%       75%      max
# Product
# Other       81.0  132.646790   0.27  17.9000   64.600  147.4700  2544.60  \
# Product_1   19.0   99.960526   3.40  46.8550   75.880  107.4200   441.99
# Product_10  17.0   97.610588   3.63  36.2400   85.330  121.6500   258.01
# Product_11  12.0  120.550833  21.70  61.6225   78.720  142.3325   333.79
# Product_12  14.0   77.138571   2.37  30.6700   62.570  108.5425   207.17
# Product_13  17.0   88.629412  12.86  18.2100   54.910  145.8400   274.59
# Product_14  10.0   95.544000   4.15  17.6350   40.905  102.9875   469.65
# Product_15  19.0   89.121053   5.71  24.2300   39.720  140.4600   409.83
# Product_16  13.0   77.116154   4.52  11.2800   46.950   91.9800   395.76
# Product_17  21.0  127.157143   5.39  54.6500  120.080  180.6100   284.74
# Product_18  11.0  107.107273   1.90  18.7450   97.780  139.1000   417.05
# ...

# %%
df_test_e =df.copy()

# %%
product_list = df['Product'].unique()
product_list
# Out:
# array([nan, 'Product_40', 'Product_1', 'Product_6', 'Product_44',
#        'Product_21', 'Product_31', 'Product_20', 'Product_34',
#        'Product_3', 'Product_35', 'Product_50', 'Product_4', 'Product_19',
#        'Product_23', 'Product_13', 'Product_9', 'Product_48',
#        'Product_26', 'Product_42', 'Product_14', 'Product_5',
#        'Product_37', 'Product_12', 'Product_8', 'Product_39',
#        'Product_17', 'Product_29', 'Product_47', 'Product_36',
#        'Product_43', 'Product_16', 'Product_32', 'Product_10',
#        'Product_15', 'Product_27', 'Product_22', 'Product_28',
#        'Product_45', 'Product_25', 'Product_11', 'Product_46',
#        'Product_2', 'Product_33', 'Product_49', 'Product_24',
#        'Product_41', 'Product_18', 'Product_7', 'Product_30',
#        'Product_38'], dtype=object)

# %%
product_list = product_list[1:]

# %%
product_list
# Out:
# array(['Product_40', 'Product_1', 'Product_6', 'Product_44', 'Product_21',
#        'Product_31', 'Product_20', 'Product_34', 'Product_3',
#        'Product_35', 'Product_50', 'Product_4', 'Product_19',
#        'Product_23', 'Product_13', 'Product_9', 'Product_48',
#        'Product_26', 'Product_42', 'Product_14', 'Product_5',
#        'Product_37', 'Product_12', 'Product_8', 'Product_39',
#        'Product_17', 'Product_29', 'Product_47', 'Product_36',
#        'Product_43', 'Product_16', 'Product_32', 'Product_10',
#        'Product_15', 'Product_27', 'Product_22', 'Product_28',
#        'Product_45', 'Product_25', 'Product_11', 'Product_46',
#        'Product_2', 'Product_33', 'Product_49', 'Product_24',
#        'Product_41', 'Product_18', 'Product_7', 'Product_30',
#        'Product_38'], dtype=object)

# %%
import numpy as np

# %%
missing_data = df_test_e['Product'].isnull().sum()
missing_data
# Out:
# 91

# %%
random_products = np.random.choice(product_list, size=missing_data)
random_products
# Out:
# array(['Product_2', 'Product_23', 'Product_50', 'Product_48',
#        'Product_37', 'Product_3', 'Product_2', 'Product_49', 'Product_34',
#        'Product_21', 'Product_1', 'Product_27', 'Product_24', 'Product_8',
#        'Product_7', 'Product_42', 'Product_41', 'Product_22',
#        'Product_25', 'Product_45', 'Product_46', 'Product_48',
#        'Product_1', 'Product_32', 'Product_45', 'Product_38',
#        'Product_42', 'Product_37', 'Product_9', 'Product_36',
#        'Product_35', 'Product_13', 'Product_21', 'Product_28',
#        'Product_3', 'Product_34', 'Product_21', 'Product_30',
#        'Product_31', 'Product_18', 'Product_42', 'Product_18',
#        'Product_39', 'Product_44', 'Product_50', 'Product_19',
#        'Product_23', 'Product_2', 'Product_36', 'Product_48',
#        'Product_31', 'Product_17', 'Product_44', 'Product_2',
#        'Product_25', 'Product_34', 'Product_30', 'Product_28',
# ...

# %%
df_test_e.loc[df_test_e['Product'].isnull(), 'Product']= random_products

# %%
df_test_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1038 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1038 non-null   object
#  1   Region      1038 non-null   object
#  2   Price       934 non-null    float64
#  3   Units Sold  932 non-null    float64
#  4   Sale Date   1038 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 48.7+ KB

# %%
df_test_e.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count        1038      1038   934.000000  932.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           32       112          NaN         NaN
# mean          NaN       NaN   108.184336   10.202790
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    26.442500    8.000000
# 50%           NaN       NaN    64.620000   10.000000
# 75%           NaN       NaN   141.150000   12.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   167.810334    3.258414
#
#                             Sale Date
# count                            1038
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-15 23:01:44.046242816
# min               2022-01-01 00:00:00
# 25%               2022-09-08 06:00:00
# ...

# %%
df.dropna(subset=['Product'],axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       853 non-null    float64
#  3   Units Sold  850 non-null    float64
#  4   Sale Date   947 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.4+ KB

# %%
## Cleaning the data for the missing price and units sold
df_test = df.copy()
df_test_2 = df.copy()
df_test_3 = df.copy()

# %%
df_test['Price'] = df_test['Price'].fillna(df_test['Price'].median())

# %%
df_test_2['Price'] = df_test_2['Price'].fillna(df_test_2.groupby('Product')['Price'].transform('median'))

# %%
df_test_3['Price']= df_test_3['Price'].fillna(df_test_3.groupby('Region')['Price'].transform('median'))

# %%
df_test.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   947.000000  850.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   101.769736   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    30.615000    8.000000
# 50%           NaN       NaN    64.640000   10.000000
# 75%           NaN       NaN   127.950000   13.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   143.472656    3.294726
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
df_test_2.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   947.000000  850.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   101.978501   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    30.615000    8.000000
# 50%           NaN       NaN    62.990000   10.000000
# 75%           NaN       NaN   127.950000   13.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   143.583608    3.294726
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
df_test_3.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   947.000000  850.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   101.598738   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    30.615000    8.000000
# 50%           NaN       NaN    64.270000   10.000000
# 75%           NaN       NaN   127.950000   13.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   143.571631    3.294726
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
df.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   853.000000  850.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   105.861407   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    27.100000    8.000000
# 50%           NaN       NaN    64.640000   10.000000
# 75%           NaN       NaN   140.000000   13.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   150.620681    3.294726
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       947 non-null    float64
#  3   Units Sold  850 non-null    float64
#  4   Sale Date   947 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.4+ KB

# %%
df_test = df.copy()
df_test_2 = df.copy()
df_test_3 = df.copy()

# %%
df_test['Units Sold']=df_test['Units Sold'].fillna(df_test['Units Sold'].median())
df_test_2['Units Sold']= df_test_2['Units Sold'].fillna(df_test_2['Units Sold'].median())
df_test_3['Units Sold']= df_test_3['Units Sold'].fillna(df_test_3['Units Sold'].median())

# %%
df_test.describe()
# Out:
#              Price  Units Sold                      Sale Date
# count   947.000000  947.000000                            947
# mean    105.861407   10.201690  2023-05-18 23:11:20.464625152
# min       0.190000    2.000000            2022-01-02 00:00:00
# 25%      30.615000    8.000000            2022-09-12 00:00:00
# 50%      79.240000   10.000000            2023-05-23 00:00:00
# 75%     127.950000   12.000000            2024-01-25 12:00:00
# max    2636.900000   22.000000            2024-09-25 00:00:00
# std     142.941665    3.121987                            NaN

# %%
df_test_2.describe()
# Out:
#              Price  Units Sold                      Sale Date
# count   947.000000  947.000000                            947
# mean    105.861407   10.201690  2023-05-18 23:11:20.464625152
# min       0.190000    2.000000            2022-01-02 00:00:00
# 25%      30.615000    8.000000            2022-09-12 00:00:00
# 50%      79.240000   10.000000            2023-05-23 00:00:00
# 75%     127.950000   12.000000            2024-01-25 12:00:00
# max    2636.900000   22.000000            2024-09-25 00:00:00
# std     142.941665    3.121987                            NaN

# %%
df_test_3.describe()
# Out:
#              Price  Units Sold                      Sale Date
# count   947.000000  947.000000                            947
# mean    105.861407   10.201690  2023-05-18 23:11:20.464625152
# min       0.190000    2.000000            2022-01-02 00:00:00
# 25%      30.615000    8.000000            2022-09-12 00:00:00
# 50%      79.240000   10.000000            2023-05-23 00:00:00
# 75%     127.950000   12.000000            2024-01-25 12:00:00
# max    2636.900000   22.000000            2024-09-25 00:00:00
# std     142.941665    3.121987                            NaN

# %%
df.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   947.000000  850.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   105.861407   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    30.615000    8.000000
# 50%           NaN       NaN    79.240000   10.000000
# 75%           NaN       NaN   127.950000   13.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   142.941665    3.294726
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
df['Units Sold']= df['Units Sold'].fillna(df['Units Sold'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       947 non-null    float64
#  3   Units Sold  947 non-null    float64
#  4   Sale Date   947 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.4+ KB

# %%
df.describe(include='all')
# Out:
#           Product    Region        Price  Units Sold
# count         947       947   947.000000  947.000000  \
# unique         50        11          NaN         NaN
# top     Product_4  Region_5          NaN         NaN
# freq           30       100          NaN         NaN
# mean          NaN       NaN   105.861407   10.224706
# min           NaN       NaN     0.190000    2.000000
# 25%           NaN       NaN    30.615000    8.000000
# 50%           NaN       NaN    79.240000   10.224706
# 75%           NaN       NaN   127.950000   12.000000
# max           NaN       NaN  2636.900000   22.000000
# std           NaN       NaN   142.941665    3.121243
#
#                             Sale Date
# count                             947
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-05-18 23:11:20.464625152
# min               2022-01-02 00:00:00
# 25%               2022-09-12 00:00:00
# ...

# %%
#Outlier Analysis
sns.boxplot(data=df, y='Price')
# Out:
# <Axes: ylabel='Price'>

# %%
drop_price_outliers = df[df['Price']>1000].index

# %%
drop_price_outliers
# Out:
# Index([269, 407, 421], dtype='int64')

# %%
df.drop(drop_price_outliers, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 944 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     944 non-null    object
#  1   Region      944 non-null    object
#  2   Price       944 non-null    float64
#  3   Units Sold  944 non-null    float64
#  4   Sale Date   944 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.2+ KB

# %%
sns.boxplot(data= df, y='Units Sold')
# Out:
# <Axes: ylabel='Units Sold'>

# %%
df['Units Sold'].sort_values(ascending=False).head(10)
# Out:
# 559    22.0
# 436    21.0
# 712    21.0
# 5      20.0
# 841    19.0
# 939    19.0
# 97     19.0
# 399    18.0
# 487    18.0
# 703    18.0
# Name: Units Sold, dtype: float64

# %%
drop_unit_outliers = df[df['Units Sold'] >= 19].index

# %%
drop_unit_outliers
# Out:
# Index([5, 97, 436, 559, 712, 841, 939], dtype='int64')

# %%
df.drop(drop_unit_outliers, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 937 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     937 non-null    object
#  1   Region      937 non-null    object
#  2   Price       937 non-null    float64
#  3   Units Sold  937 non-null    float64
#  4   Sale Date   937 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 43.9+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890 entries, 1 to 998
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     890 non-null    object
#  1   Region      890 non-null    object
#  2   Price       890 non-null    float64
#  3   Units Sold  890 non-null    float64
#  4   Sale Date   890 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 41.7+ KB

# %%
##Data Exploration 
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df['Units Sold'])
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %%
#Now let's check our categorical variables.
df.groupby('Product')['Units Sold'].count().sort_values(ascending=False).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Region')['Units Sold'].count().sort_values(ascending=False).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_product = df.groupby('Product')['Units Sold'].aggregate(['sum','mean','median','count'])
units_by_product.head(10)
# Out:
#                    sum       mean     median  count
# Product
# Product_1   201.674118  10.083706  10.224706     20
# Product_10  222.449412  11.122471  11.112353     20
# Product_11  130.224706  10.852059  11.000000     12
# Product_12  121.224706  10.102059  10.000000     12
# Product_13  181.449412  10.673495  10.224706     17
# Product_14  127.000000  10.583333  10.500000     12
# Product_15  215.449412  10.772471  10.224706     20
# Product_16  161.224706  10.748314  11.000000     15
# Product_17  206.674118   9.841625  10.224706     21
# Product_18  144.224706  12.018725  12.000000     12

# %%
units_by_product['sum'].sort_values(ascending=False).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Product'>

# %%
units_by_product['mean'].sort_values(ascending=False).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Product')['Price'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df['Revenue']= df['Price']* df['Units Sold']

# %%
df
# Out:
#         Product     Region       Price  Units Sold  Sale Date      Revenue
# 1    Product_40   Region_2   46.190000        10.0 2022-01-02   461.900000
# 2     Product_1   Region_5  105.861407         4.0 2022-01-03   423.445627
# 3     Product_6   Region_8  143.470000         8.0 2022-01-04  1147.760000
# 4    Product_44   Region_4  122.540000        10.0 2022-01-05  1225.400000
# 6    Product_31  Region_10    1.600000        11.0 2022-01-07    17.600000
# ..          ...        ...         ...         ...        ...          ...
# 994  Product_19   Region_8   83.760000         6.0 2024-09-21   502.560000
# 995  Product_41   Region_5   13.160000         7.0 2024-09-22    92.120000
# 996  Product_34   Region_8   70.220000        15.0 2024-09-23  1053.300000
# 997   Product_3   Region_9   42.790000         7.0 2024-09-24   299.530000
# 998  Product_38   Region_7   44.680000        16.0 2024-09-25   714.880000
#
# [890 rows x 6 columns]
