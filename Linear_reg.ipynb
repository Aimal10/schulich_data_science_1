# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

import seaborn as sns

# %%
df = pd.read_csv('/Users/aimaldastagirzada/Downloads/archive (6)/Car details v3.csv')

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel  \
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC  \
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.describe(include='all')
# Out:
#                           name         year  selling_price     km_driven
# count                     8128  8128.000000   8.128000e+03  8.128000e+03  \
# unique                    2058          NaN            NaN           NaN
# top     Maruti Swift Dzire VDI          NaN            NaN           NaN
# freq                       129          NaN            NaN           NaN
# mean                       NaN  2013.804011   6.382718e+05  6.981951e+04
# std                        NaN     4.044249   8.062534e+05  5.655055e+04
# min                        NaN  1983.000000   2.999900e+04  1.000000e+00
# 25%                        NaN  2011.000000   2.549990e+05  3.500000e+04
# 50%                        NaN  2015.000000   4.500000e+05  6.000000e+04
# 75%                        NaN  2017.000000   6.750000e+05  9.800000e+04
# max                        NaN  2020.000000   1.000000e+07  2.360457e+06
#
#           fuel seller_type transmission        owner    mileage   engine
# count     8128        8128         8128         8128       7907     7907  \
# unique       4           3            2            5        393      121
# top     Diesel  Individual       Manual  First Owner  18.9 kmpl  1248 CC
# freq      4402        6766         7078         5289        225     1017
# mean       NaN         NaN          NaN          NaN        NaN      NaN
# std        NaN         NaN          NaN          NaN        NaN      NaN
# min        NaN         NaN          NaN          NaN        NaN      NaN
# 25%        NaN         NaN          NaN          NaN        NaN      NaN
# 50%        NaN         NaN          NaN          NaN        NaN      NaN
# 75%        NaN         NaN          NaN          NaN        NaN      NaN
# max        NaN         NaN          NaN          NaN        NaN      NaN
#
#        max_power          torque        seats
# count       7913            7906  7907.000000
# unique       322             441          NaN
# top       74 bhp  190Nm@ 2000rpm          NaN
# freq         377             530          NaN
# mean         NaN             NaN     5.416719
# std          NaN             NaN     0.959588
# min          NaN             NaN     2.000000
# 25%          NaN             NaN     5.000000
# 50%          NaN             NaN     5.000000
# 75%          NaN             NaN     5.000000
# max          NaN             NaN    14.000000

# %%
df.drop(columns=['name'], inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission
# 0     2014         450000     145500  Diesel  Individual       Manual  \
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner     mileage   engine   max_power
# 0              First Owner   23.4 kmpl  1248 CC      74 bhp  \
# 1             Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2              Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3              First Owner   23.0 kmpl  1396 CC      90 bhp
# 4              First Owner   16.1 kmpl  1298 CC    88.2 bhp
# ...                    ...         ...      ...         ...
# 8123           First Owner   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Fourth & Above Owner   16.8 kmpl  1493 CC     110 bhp
# 8125           First Owner   19.3 kmpl  1248 CC    73.9 bhp
# 8126           First Owner  23.57 kmpl  1396 CC      70 bhp
# 8127           First Owner  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 12 columns]

# %%
df.head(1)
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission
# 0  2014         450000     145500  Diesel  Individual       Manual  \
#
#          owner    mileage   engine max_power          torque  seats
# 0  First Owner  23.4 kmpl  1248 CC    74 bhp  190Nm@ 2000rpm    5.0

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df.drop(columns=['torque'], inplace=True)

# %%
df.describe(include='all')
# Out:
#                year  selling_price     km_driven    fuel seller_type
# count   8128.000000   8.128000e+03  8.128000e+03    8128        8128  \
# unique          NaN            NaN           NaN       4           3
# top             NaN            NaN           NaN  Diesel  Individual
# freq            NaN            NaN           NaN    4402        6766
# mean    2013.804011   6.382718e+05  6.981951e+04     NaN         NaN
# std        4.044249   8.062534e+05  5.655055e+04     NaN         NaN
# min     1983.000000   2.999900e+04  1.000000e+00     NaN         NaN
# 25%     2011.000000   2.549990e+05  3.500000e+04     NaN         NaN
# 50%     2015.000000   4.500000e+05  6.000000e+04     NaN         NaN
# 75%     2017.000000   6.750000e+05  9.800000e+04     NaN         NaN
# max     2020.000000   1.000000e+07  2.360457e+06     NaN         NaN
#
#        transmission        owner    mileage   engine max_power        seats
# count          8128         8128       7907     7907      7913  7907.000000
# unique            2            5        393      121       322          NaN
# top          Manual  First Owner  18.9 kmpl  1248 CC    74 bhp          NaN
# freq           7078         5289        225     1017       377          NaN
# mean            NaN          NaN        NaN      NaN       NaN     5.416719
# std             NaN          NaN        NaN      NaN       NaN     0.959588
# min             NaN          NaN        NaN      NaN       NaN     2.000000
# 25%             NaN          NaN        NaN      NaN       NaN     5.000000
# 50%             NaN          NaN        NaN      NaN       NaN     5.000000
# 75%             NaN          NaN        NaN      NaN       NaN     5.000000
# max             NaN          NaN        NaN      NaN       NaN    14.000000

# %% [markdown]
# **Can we do feature engineering before data cleaning?**

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %% [markdown]
# Ouliter-Selling price, KM driven

# %%
df.head(10)
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission
# 0  2014         450000     145500  Diesel  Individual       Manual  \
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
# 5  2017         440000      45000  Petrol  Individual       Manual
# 6  2007          96000     175000     LPG  Individual       Manual
# 7  2001          45000       5000  Petrol  Individual       Manual
# 8  2011         350000      90000  Diesel  Individual       Manual
# 9  2013         200000     169000  Diesel  Individual       Manual
#
#           owner     mileage   engine   max_power  seats
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp    5.0
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp    5.0
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp    5.0
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp    5.0
# 5   First Owner  20.14 kmpl  1197 CC   81.86 bhp    5.0
# 6   First Owner  17.3 km/kg  1061 CC    57.5 bhp    5.0
# 7  Second Owner   16.1 kmpl   796 CC      37 bhp    4.0
# 8   First Owner  23.59 kmpl  1364 CC    67.1 bhp    5.0
# 9   First Owner   20.0 kmpl  1399 CC    68.1 bhp    5.0

# %%
import pandas as pd
import re

# Assuming you have loaded your dataset into a DataFrame named 'df'

# Columns to remove text from
columns_to_clean = ['mileage', 'engine', 'max_power']

# Function to remove text and extract numerical part from each cell using regex
def extract_numerical(cell):
    if isinstance(cell, str):
        numerical_part = re.findall(r'\d+\.\d+|\d+', cell)
        return float(numerical_part[0]) if numerical_part else None
    return None

# Apply the function to the specified columns using str.replace
for column in columns_to_clean:
    df[column] = df[column].str.replace(r'\D+', '').apply(extract_numerical)

print(df)
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission
# 0     2014         450000     145500  Diesel  Individual       Manual  \
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats
# 0              First Owner    23.40  1248.0      74.00    5.0
# 1             Second Owner    21.14  1498.0     103.52    5.0
# 2              Third Owner    17.70  1497.0      78.00    5.0
# 3              First Owner    23.00  1396.0      90.00    5.0
# 4              First Owner    16.10  1298.0      88.20    5.0
# ...                    ...      ...     ...        ...    ...
# 8123           First Owner    18.50  1197.0      82.85    5.0
# 8124  Fourth & Above Owner    16.80  1493.0     110.00    5.0
# 8125           First Owner    19.30  1248.0      73.90    5.0
# 8126           First Owner    23.57  1396.0      70.00    5.0
# 8127           First Owner    23.57  1396.0      70.00    5.0
#
# [8128 rows x 11 columns]

# %%
df.head(10)
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission
# 0  2014         450000     145500  Diesel  Individual       Manual  \
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
# 5  2017         440000      45000  Petrol  Individual       Manual
# 6  2007          96000     175000     LPG  Individual       Manual
# 7  2001          45000       5000  Petrol  Individual       Manual
# 8  2011         350000      90000  Diesel  Individual       Manual
# 9  2013         200000     169000  Diesel  Individual       Manual
#
#           owner  mileage  engine  max_power  seats
# 0   First Owner    23.40  1248.0      74.00    5.0
# 1  Second Owner    21.14  1498.0     103.52    5.0
# 2   Third Owner    17.70  1497.0      78.00    5.0
# 3   First Owner    23.00  1396.0      90.00    5.0
# 4   First Owner    16.10  1298.0      88.20    5.0
# 5   First Owner    20.14  1197.0      81.86    5.0
# 6   First Owner    17.30  1061.0      57.50    5.0
# 7  Second Owner    16.10   796.0      37.00    4.0
# 8   First Owner    23.59  1364.0      67.10    5.0
# 9   First Owner    20.00  1399.0      68.10    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  seats          7907 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 698.6+ KB

# %%
df.describe(include='all')
# Out:
#                year  selling_price     km_driven    fuel seller_type
# count   8128.000000   8.128000e+03  8.128000e+03    8128        8128  \
# unique          NaN            NaN           NaN       4           3
# top             NaN            NaN           NaN  Diesel  Individual
# freq            NaN            NaN           NaN    4402        6766
# mean    2013.804011   6.382718e+05  6.981951e+04     NaN         NaN
# std        4.044249   8.062534e+05  5.655055e+04     NaN         NaN
# min     1983.000000   2.999900e+04  1.000000e+00     NaN         NaN
# 25%     2011.000000   2.549990e+05  3.500000e+04     NaN         NaN
# 50%     2015.000000   4.500000e+05  6.000000e+04     NaN         NaN
# 75%     2017.000000   6.750000e+05  9.800000e+04     NaN         NaN
# max     2020.000000   1.000000e+07  2.360457e+06     NaN         NaN
#
#        transmission        owner      mileage       engine    max_power
# count          8128         8128  7907.000000  7907.000000  7912.000000  \
# unique            2            5          NaN          NaN          NaN
# top          Manual  First Owner          NaN          NaN          NaN
# freq           7078         5289          NaN          NaN          NaN
# mean            NaN          NaN    19.418783  1458.625016    91.517919
# std             NaN          NaN     4.037145   503.916303    35.822499
# min             NaN          NaN     0.000000   624.000000     0.000000
# 25%             NaN          NaN    16.780000  1197.000000    68.050000
# 50%             NaN          NaN    19.300000  1248.000000    82.000000
# 75%             NaN          NaN    22.320000  1582.000000   102.000000
# max             NaN          NaN    42.000000  3604.000000   400.000000
#
#               seats
# count   7907.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       5.416719
# std        0.959588
# min        2.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max       14.000000

# %% [markdown]
# Ouliter-Selling price, KM driven, mileage, engine, maxpower, maxseat

# %%
#Box plot to chck for outliers
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  seats          7907 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 698.6+ KB

# %%
df[df['selling_price']>=10000000]
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission
# 170  2017       10000000      30000  Petrol  Individual    Automatic  \
#
#            owner  mileage  engine  max_power  seats
# 170  First Owner     42.0  1969.0      400.0    4.0

# %%
df = df[df['selling_price'] < 10000000]

# %%
df['selling_price'].describe()
# Out:
# count    8.127000e+03
# mean     6.371199e+05
# std      7.995860e+05
# min      2.999900e+04
# 25%      2.549990e+05
# 50%      4.500000e+05
# 75%      6.750000e+05
# max      7.200000e+06
# Name: selling_price, dtype: float64

# %%
df[df['selling_price']>650000]
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission
# 16    2016         778000      70000  Diesel  Individual       Manual  \
# 19    2016         680000     100000  Diesel  Individual       Manual
# 21    2017         950000      50000  Diesel  Individual       Manual
# 30    2017         670000      70000  Diesel  Individual       Manual
# 33    2018         730000       2388  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8099  2013         750000     120000  Diesel  Individual       Manual
# 8100  2018         800000      85000  Diesel  Individual       Manual
# 8108  2019        1575000      20000  Diesel  Individual    Automatic
# 8109  2018         750000      24000  Diesel  Individual       Manual
# 8112  2018         746000      24000  Diesel  Individual       Manual
#
#              owner  mileage  engine  max_power  seats
# 16    Second Owner    24.52  1248.0      88.50    7.0
# 19     First Owner    22.54  1396.0      88.73    5.0
# 21     First Owner    25.50  1498.0      98.60    5.0
# 30     First Owner    24.30  1248.0      88.50    5.0
# 33     First Owner    18.60  1197.0      81.83    5.0
# ...            ...      ...     ...        ...    ...
# 8099   First Owner    15.10  2179.0     140.00    7.0
# 8100  Second Owner    21.50  1497.0     108.50    5.0
# 8108   First Owner    17.80  1493.0     113.40    5.0
# 8109   First Owner    24.40  1498.0      98.63    5.0
# 8112   First Owner    24.40  1498.0      98.63    5.0
#
# [2123 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8127 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8127 non-null   int64
#  1   selling_price  8127 non-null   int64
#  2   km_driven      8127 non-null   int64
#  3   fuel           8127 non-null   object
#  4   seller_type    8127 non-null   object
#  5   transmission   8127 non-null   object
#  6   owner          8127 non-null   object
#  7   mileage        7906 non-null   float64
#  8   engine         7906 non-null   float64
#  9   max_power      7911 non-null   float64
#  10  seats          7906 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 761.9+ KB

# %%
#Box plot to chck for outliers
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df['selling_price'].describe()
# Out:
# count    8.127000e+03
# mean     6.371199e+05
# std      7.995860e+05
# min      2.999900e+04
# 25%      2.549990e+05
# 50%      4.500000e+05
# 75%      6.750000e+05
# max      7.200000e+06
# Name: selling_price, dtype: float64

# %%
df = df[df['selling_price'] < 3500000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7952 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7952 non-null   int64
#  1   selling_price  7952 non-null   int64
#  2   km_driven      7952 non-null   int64
#  3   fuel           7952 non-null   object
#  4   seller_type    7952 non-null   object
#  5   transmission   7952 non-null   object
#  6   owner          7952 non-null   object
#  7   mileage        7731 non-null   float64
#  8   engine         7731 non-null   float64
#  9   max_power      7736 non-null   float64
#  10  seats          7731 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 745.5+ KB

# %%
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7952 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7952 non-null   int64
#  1   selling_price  7952 non-null   int64
#  2   km_driven      7952 non-null   int64
#  3   fuel           7952 non-null   object
#  4   seller_type    7952 non-null   object
#  5   transmission   7952 non-null   object
#  6   owner          7952 non-null   object
#  7   mileage        7731 non-null   float64
#  8   engine         7731 non-null   float64
#  9   max_power      7736 non-null   float64
#  10  seats          7731 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1003.5+ KB

# %%
df['km_driven'].describe()
# Out:
# count    7.952000e+03
# mean     7.097188e+04
# std      5.661072e+04
# min      1.000000e+00
# 25%      3.500000e+04
# 50%      6.300000e+04
# 75%      1.000000e+05
# max      2.360457e+06
# Name: km_driven, dtype: float64

# %%
df = df[df['km_driven'] < 1000000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7950 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7950 non-null   int64
#  1   selling_price  7950 non-null   int64
#  2   km_driven      7950 non-null   int64
#  3   fuel           7950 non-null   object
#  4   seller_type    7950 non-null   object
#  5   transmission   7950 non-null   object
#  6   owner          7950 non-null   object
#  7   mileage        7729 non-null   float64
#  8   engine         7729 non-null   float64
#  9   max_power      7734 non-null   float64
#  10  seats          7729 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 745.3+ KB

# %%
df['km_driven'].describe()
# Out:
# count      7950.000000
# mean      70504.143270
# std       47843.878999
# min           1.000000
# 25%       35000.000000
# 50%       63000.000000
# 75%      100000.000000
# max      577414.000000
# Name: km_driven, dtype: float64

# %%
df[df['km_driven']<= 1]
# Out:
#       year  selling_price  km_driven fuel seller_type transmission
# 7913  2011         209000          1  CNG  Individual       Manual  \
#
#                      owner  mileage  engine  max_power  seats
# 7913  Fourth & Above Owner     15.1  1196.0       73.0    5.0

# %%
df=df[df['km_driven'] > 1]

# %%
df['km_driven'].describe()
# Out:
# count      7949.000000
# mean      70513.012706
# std       47840.351993
# min        1000.000000
# 25%       35000.000000
# 50%       63000.000000
# 75%      100000.000000
# max      577414.000000
# Name: km_driven, dtype: float64

# %%
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df=df[df['km_driven'] <330000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7935 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7935 non-null   int64
#  1   selling_price  7935 non-null   int64
#  2   km_driven      7935 non-null   int64
#  3   fuel           7935 non-null   object
#  4   seller_type    7935 non-null   object
#  5   transmission   7935 non-null   object
#  6   owner          7935 non-null   object
#  7   mileage        7714 non-null   float64
#  8   engine         7714 non-null   float64
#  9   max_power      7719 non-null   float64
#  10  seats          7714 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 743.9+ KB

# %%
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df['engine'].describe()
# Out:
# count    7714.000000
# mean     1439.725434
# std       490.661160
# min       624.000000
# 25%      1197.000000
# 50%      1248.000000
# 75%      1498.000000
# max      3498.000000
# Name: engine, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7935 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7935 non-null   int64
#  1   selling_price  7935 non-null   int64
#  2   km_driven      7935 non-null   int64
#  3   fuel           7935 non-null   object
#  4   seller_type    7935 non-null   object
#  5   transmission   7935 non-null   object
#  6   owner          7935 non-null   object
#  7   mileage        7714 non-null   float64
#  8   engine         7714 non-null   float64
#  9   max_power      7719 non-null   float64
#  10  seats          7714 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1001.9+ KB

# %%
df=df[df['engine'] <2800]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7624 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7624 non-null   int64
#  1   selling_price  7624 non-null   int64
#  2   km_driven      7624 non-null   int64
#  3   fuel           7624 non-null   object
#  4   seller_type    7624 non-null   object
#  5   transmission   7624 non-null   object
#  6   owner          7624 non-null   object
#  7   mileage        7624 non-null   float64
#  8   engine         7624 non-null   float64
#  9   max_power      7623 non-null   float64
#  10  seats          7624 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 714.8+ KB

# %%
fig, axs = plt.subplots(2,3, figsize = (10,10))
plt1 = sns.boxplot(df['selling_price'], ax = axs[0,0])
plt2 = sns.boxplot(df['km_driven'], ax = axs[0,1])
plt3 = sns.boxplot(df['mileage'], ax = axs[0,2])
plt4 = sns.boxplot(df['engine'], ax = axs[1,0])
plt5 = sns.boxplot(df['max_power'], ax = axs[1,1])

plt.tight_layout()

# %%
df['max_power'].describe()
# Out:
# count    7623.000000
# mean       88.040886
# std        29.778793
# min        32.800000
# 25%        68.000000
# 50%        81.860000
# 75%       100.000000
# max       218.000000
# Name: max_power, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7624 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7624 non-null   int64
#  1   selling_price  7624 non-null   int64
#  2   km_driven      7624 non-null   int64
#  3   fuel           7624 non-null   object
#  4   seller_type    7624 non-null   object
#  5   transmission   7624 non-null   object
#  6   owner          7624 non-null   object
#  7   mileage        7624 non-null   float64
#  8   engine         7624 non-null   float64
#  9   max_power      7623 non-null   float64
#  10  seats          7624 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 972.8+ KB

# %%
df=df[df['max_power'] <200]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7612 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7612 non-null   int64
#  1   selling_price  7612 non-null   int64
#  2   km_driven      7612 non-null   int64
#  3   fuel           7612 non-null   object
#  4   seller_type    7612 non-null   object
#  5   transmission   7612 non-null   object
#  6   owner          7612 non-null   object
#  7   mileage        7612 non-null   float64
#  8   engine         7612 non-null   float64
#  9   max_power      7612 non-null   float64
#  10  seats          7612 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 713.6+ KB

# %%
df2 =df.copy()

# %%
df2
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission
# 0     2014         450000     145500  Diesel  Individual       Manual  \
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats
# 0              First Owner    23.40  1248.0      74.00    5.0
# 1             Second Owner    21.14  1498.0     103.52    5.0
# 2              Third Owner    17.70  1497.0      78.00    5.0
# 3              First Owner    23.00  1396.0      90.00    5.0
# 4              First Owner    16.10  1298.0      88.20    5.0
# ...                    ...      ...     ...        ...    ...
# 8123           First Owner    18.50  1197.0      82.85    5.0
# 8124  Fourth & Above Owner    16.80  1493.0     110.00    5.0
# 8125           First Owner    19.30  1248.0      73.90    5.0
# 8126           First Owner    23.57  1396.0      70.00    5.0
# 8127           First Owner    23.57  1396.0      70.00    5.0
#
# [7612 rows x 11 columns]

# %%
df2['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
def change_transmission(x):
    if x=='Automatic':
        return 1
    else:
        return 0
    
df2['transmission'] = df2['transmission'].apply(change_transmission)

# %%
df2['transmission'].value_counts()
# Out:
# transmission
# 0    6806
# 1     806
# Name: count, dtype: int64

# %%
df2['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7612 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7612 non-null   int64
#  1   selling_price  7612 non-null   int64
#  2   km_driven      7612 non-null   int64
#  3   fuel           7612 non-null   object
#  4   seller_type    7612 non-null   object
#  5   transmission   7612 non-null   int64
#  6   owner          7612 non-null   object
#  7   mileage        7612 non-null   float64
#  8   engine         7612 non-null   float64
#  9   max_power      7612 non-null   float64
#  10  seats          7612 non-null   float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 713.6+ KB

# %%
df2['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
def change_fuel(x):
    if x=='Diesel':
        return 1
    elif x=='Petrol':
        return 2
    elif x=='LPG':
        return 3
    elif x=='CNG':
        return 4
    
df2['fuel'] = df2['fuel'].apply(change_transmission)

# %%
df2['fuel'].value_counts()
# Out:
# fuel
# 0    7612
# Name: count, dtype: int64

# %%
results = ols("selling_price ~ transmission +km_driven +mileage + max_power + fuel + seller_type", data= df2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          selling_price   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     2165.
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:10:53   Log-Likelihood:            -1.0627e+05
# No. Observations:                7612   AIC:                         2.126e+05
# Df Residuals:                    7605   BIC:                         2.126e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                       -4.425e+05   2.78e+04    -15.930      0.000   -4.97e+05   -3.88e+05
# seller_type[T.Individual]       -1.411e+05   1.04e+04    -13.563      0.000   -1.61e+05   -1.21e+05
# seller_type[T.Trustmark Dealer] -7.346e+04   2.05e+04     -3.587      0.000   -1.14e+05   -3.33e+04
# transmission                     2.719e+05   1.21e+04     22.424      0.000    2.48e+05    2.96e+05
# km_driven                          -1.8102      0.075    -23.994      0.000      -1.958      -1.662
# mileage                          1.483e+04    895.592     16.557      0.000    1.31e+04    1.66e+04
# max_power                        1.036e+04    129.351     80.079      0.000    1.01e+04    1.06e+04
# fuel                                     0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     1819.924   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11030.717
# Skew:                           1.006   Prob(JB):                         0.00
# Kurtosis:                       8.544   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Users/aimaldastagirzada/Library/Python/3.9/lib/python/site-packages/statsmodels/regression/linear_model.py:1965: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
"y_hat =  -2.543e+05 + 3.058e+05  transmission  -2.3759 km_driven + 1.577e+04 mileage+ 9308.5418 max_power  -1.309e+05 fuel + 8.606e+04seller_type"
# Out:
# 'y_hat =  -2.543e+05 + 3.058e+05  transmission  -2.3759 km_driven + 1.577e+04 mileage+ 9308.5418 max_power  -1.309e+05 fuel + 8.606e+04seller_type'

# %%
df2.head(1)
# Out:
#    year  selling_price  km_driven  fuel seller_type  transmission
# 0  2014         450000     145500     0  Individual             0  \
#
#          owner  mileage  engine  max_power  seats
# 0  First Owner     23.4  1248.0       74.0    5.0

# %%
 -2.543e+05 + 3.058e+05 *(0)  -2.3759*(145500) + 1.577e+04*(23.4)+ 9308.5418*(74.0)  -1.309e+05*(1) + 8.606e+04*(1)
# Out:
# 413016.64320000017

# %%
pred_vals = results.predict(df2[['transmission','km_driven','mileage', 'max_power', 'fuel', 'seller_type' ]])
pred_vals
# Out:
# 0       267770.194288
# 1       585390.741690
# 2       233237.793878
# 3       460808.392929
# 4       350867.885880
#             ...
# 8123    349722.043023
# 8124    588887.214426
# 8125    251053.294951
# 8126    446731.148693
# 8127    446731.148693
# Length: 7612, dtype: float64

# %%
res = pd.concat([pred_vals.to_frame().rename(columns={0:'y_hat'}),df2['selling_price']], axis=1)

# %%
res
# Out:
#               y_hat  selling_price
# 0     266535.376336         450000
# 1     584959.976240         370000
# 2     233404.324260         158000
# 3     459825.052653         225000
# 4     351537.574404         130000
# ...             ...            ...
# 8123  349810.176324         320000
# 8124  589537.804598         135000
# 8125  250864.197754         382000
# 8126  445751.118725         290000
# 8127  445751.118725         290000
#
# [7612 rows x 2 columns]

# %%
res['error'] = res['y_hat'] - res['selling_price']

# %%
res.head(1)
# Out:
#            y_hat  selling_price          error
# 0  266535.376336         450000 -183464.623664

# %%
res['sq_error'] = res['error']**2

# %%
np.sqrt(res['sq_error'].mean())
# Out:
# 279882.0303541486

# %%
plt.hist(res['error'])
# Out:
# (array([1.000e+01, 5.000e+01, 3.800e+01, 1.560e+02, 8.730e+02, 4.424e+03,
#         1.815e+03, 2.060e+02, 3.600e+01, 4.000e+00]),
#  array([-1855410.29102621, -1524455.32210209, -1193500.35317797,
#          -862545.38425385,  -531590.41532973,  -200635.44640561,
#           130319.52251851,   461274.49144263,   792229.46036675,
#          1123184.42929087,  1454139.39821499]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df2['transmission'], res  ['error'])

# %%
plt.scatter(df2['km_driven'], res  ['error'])

# %%
plt.scatter(df2['mileage'], res  ['error'])

# %%
plt.scatter(df2['max_power'], res  ['error'])

# %%
plt.scatter(df2['fuel'], res  ['error'])

# %%
import scipy.stats as stats
fig = plt.figure()
ax = fig.add_subplot(111)
stats.probplot(res['error'], dist='norm', plot=ax)
# Out:
# ((array([-3.7426203 , -3.51362044, -3.38771506, ...,  3.38771506,
#           3.51362044,  3.7426203 ]),
#   array([-1855410.29102621, -1855410.29102621, -1679433.38688129, ...,
#           1172055.24457862,  1302070.94110851,  1454139.39821499])),
#  (268157.5972346047, -1.3369544205136883e-06, 0.9576710647015305))

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
#       dfb_Intercept  dfb_seller_type[T.Individual]
# 0         -0.007848                       0.000741  \
# 1          0.010023                      -0.002920
# 2         -0.000671                      -0.000037
# 3          0.012117                      -0.002495
# 4         -0.004030                      -0.001002
# ...             ...                            ...
# 8123      -0.000103                      -0.000198
# 8124       0.005361                      -0.005188
# 8125       0.000390                       0.000467
# 8126       0.001567                      -0.003011
# 8127       0.001567                      -0.003011
#
#       dfb_seller_type[T.Trustmark Dealer]  dfb_transmission  dfb_km_driven
# 0                            6.074883e-04          0.002124       0.014271  \
# 1                           -1.168789e-03          0.002307      -0.009747
# 2                            6.648769e-05         -0.000402      -0.004436
# 3                           -1.190639e-03          0.000214      -0.013530
# 4                            2.211604e-04          0.001064      -0.007741
# ...                                   ...               ...            ...
# 8123                        -8.195664e-07          0.000069      -0.000935
# 8124                        -1.275767e-03          0.007658      -0.015315
# 8125                        -6.385082e-05          0.000645       0.005726
# 8126                        -1.493985e-04          0.001174       0.005838
# 8127                        -1.493985e-04          0.001174       0.005838
#
#       dfb_mileage  dfb_max_power  dfb_fuel       cooks_d  standard_resid
# 0        0.009451      -0.000642       NaN  4.047406e-05        0.655452  \
# 1       -0.008014      -0.008111       NaN  3.446751e-05       -0.767864
# 2        0.000940       0.001419       NaN  4.407567e-06       -0.269356
# 3       -0.012283      -0.005238       NaN  4.981434e-05       -0.838866
# 4        0.006410       0.001594       NaN  2.891892e-05       -0.791321
# ...           ...            ...       ...           ...             ...
# 8123     0.000193       0.000184       NaN  3.578047e-07       -0.106474
# 8124     0.004030      -0.014348       NaN  1.348758e-04       -1.623619
# 8125    -0.000055      -0.002403       NaN  9.119493e-06        0.468402
# 8126    -0.004287       0.000503       NaN  1.558312e-05       -0.556345
# 8127    -0.004287       0.000503       NaN  1.558312e-05       -0.556345
#
#       hat_diag  dffits_internal  student_resid    dffits
# 0     0.000753         0.017994       0.655428  0.017994
# 1     0.000467        -0.016605      -0.767843 -0.016605
# 2     0.000486        -0.005938      -0.269340 -0.005938
# 3     0.000566        -0.019963      -0.838850 -0.019962
# 4     0.000369        -0.015210      -0.791302 -0.015210
# ...        ...              ...            ...       ...
# 8123  0.000252        -0.001692      -0.106467 -0.001692
# 8124  0.000409        -0.032848      -1.623794 -0.032852
# 8125  0.000332         0.008541       0.468378  0.008541
# 8126  0.000403        -0.011165      -0.556319 -0.011165
# 8127  0.000403        -0.011165      -0.556319 -0.011165
#
# [7612 rows x 14 columns]
# /Users/aimaldastagirzada/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:930: RuntimeWarning: invalid value encountered in divide
#   dfbetas /= np.sqrt(np.diag(self.results.normalized_cov_params))

# %%
infl.summary_frame()
# Out:
#       dfb_Intercept  dfb_seller_type[T.Individual]
# 0         -0.007848                       0.000741  \
# 1          0.010023                      -0.002920
# 2         -0.000671                      -0.000037
# 3          0.012117                      -0.002495
# 4         -0.004030                      -0.001002
# ...             ...                            ...
# 8123      -0.000103                      -0.000198
# 8124       0.005361                      -0.005188
# 8125       0.000390                       0.000467
# 8126       0.001567                      -0.003011
# 8127       0.001567                      -0.003011
#
#       dfb_seller_type[T.Trustmark Dealer]  dfb_transmission  dfb_km_driven
# 0                            6.074883e-04          0.002124       0.014271  \
# 1                           -1.168789e-03          0.002307      -0.009747
# 2                            6.648769e-05         -0.000402      -0.004436
# 3                           -1.190639e-03          0.000214      -0.013530
# 4                            2.211604e-04          0.001064      -0.007741
# ...                                   ...               ...            ...
# 8123                        -8.195664e-07          0.000069      -0.000935
# 8124                        -1.275767e-03          0.007658      -0.015315
# 8125                        -6.385082e-05          0.000645       0.005726
# 8126                        -1.493985e-04          0.001174       0.005838
# 8127                        -1.493985e-04          0.001174       0.005838
#
#       dfb_mileage  dfb_max_power  dfb_fuel       cooks_d  standard_resid
# 0        0.009451      -0.000642       NaN  4.047406e-05        0.655452  \
# 1       -0.008014      -0.008111       NaN  3.446751e-05       -0.767864
# 2        0.000940       0.001419       NaN  4.407567e-06       -0.269356
# 3       -0.012283      -0.005238       NaN  4.981434e-05       -0.838866
# 4        0.006410       0.001594       NaN  2.891892e-05       -0.791321
# ...           ...            ...       ...           ...             ...
# 8123     0.000193       0.000184       NaN  3.578047e-07       -0.106474
# 8124     0.004030      -0.014348       NaN  1.348758e-04       -1.623619
# 8125    -0.000055      -0.002403       NaN  9.119493e-06        0.468402
# 8126    -0.004287       0.000503       NaN  1.558312e-05       -0.556345
# 8127    -0.004287       0.000503       NaN  1.558312e-05       -0.556345
#
#       hat_diag  dffits_internal  student_resid    dffits
# 0     0.000753         0.017994       0.655428  0.017994
# 1     0.000467        -0.016605      -0.767843 -0.016605
# 2     0.000486        -0.005938      -0.269340 -0.005938
# 3     0.000566        -0.019963      -0.838850 -0.019962
# 4     0.000369        -0.015210      -0.791302 -0.015210
# ...        ...              ...            ...       ...
# 8123  0.000252        -0.001692      -0.106467 -0.001692
# 8124  0.000409        -0.032848      -1.623794 -0.032852
# 8125  0.000332         0.008541       0.468378  0.008541
# 8126  0.000403        -0.011165      -0.556319 -0.011165
# 8127  0.000403        -0.011165      -0.556319 -0.011165
#
# [7612 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
df2.drop(7337, inplace= True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7611 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7611 non-null   int64
#  1   selling_price  7611 non-null   int64
#  2   km_driven      7611 non-null   int64
#  3   fuel           7611 non-null   int64
#  4   seller_type    7611 non-null   object
#  5   transmission   7611 non-null   int64
#  6   owner          7611 non-null   object
#  7   mileage        7611 non-null   float64
#  8   engine         7611 non-null   float64
#  9   max_power      7611 non-null   float64
#  10  seats          7611 non-null   float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 713.5+ KB

# %%
results = ols("selling_price ~ transmission +km_driven +mileage + max_power + fuel + seller_type", data= df2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          selling_price   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     2162.
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:11:40   Log-Likelihood:            -1.0624e+05
# No. Observations:                7611   AIC:                         2.125e+05
# Df Residuals:                    7604   BIC:                         2.125e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                        -4.48e+05   2.77e+04    -16.150      0.000   -5.02e+05   -3.94e+05
# seller_type[T.Individual]       -1.398e+05   1.04e+04    -13.467      0.000    -1.6e+05   -1.19e+05
# seller_type[T.Trustmark Dealer] -7.149e+04   2.04e+04     -3.498      0.000   -1.12e+05   -3.14e+04
# transmission                      2.71e+05   1.21e+04     22.395      0.000    2.47e+05    2.95e+05
# km_driven                          -1.8075      0.075    -24.007      0.000      -1.955      -1.660
# mileage                          1.507e+04    894.794     16.838      0.000    1.33e+04    1.68e+04
# max_power                        1.035e+04    129.096     80.185      0.000    1.01e+04    1.06e+04
# fuel                                     0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     1817.684   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10952.524
# Skew:                           1.006   Prob(JB):                         0.00
# Kurtosis:                       8.521   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Users/aimaldastagirzada/Library/Python/3.9/lib/python/site-packages/statsmodels/regression/linear_model.py:1965: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1411], line 2
#       1 infl = results.get_influence()
# ----> 2 print(infl.summary_frame())
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:1157, in OLSInfluence.summary_frame(self)
#    1149 beta_labels = ['dfb_' + i for i in data.xnames]
#    1151 # grab the results
#    1152 summary_data = DataFrame(dict(
#    1153     cooks_d=self.cooks_distance[0],
#    1154     standard_resid=self.resid_studentized_internal,
#    1155     hat_diag=self.hat_matrix_diag,
#    1156     dffits_internal=self.dffits_internal[0],
# -> 1157     student_resid=self.resid_studentized_external,
#    1158     dffits=self.dffits[0],
#    1159 ),
#    1160     index=row_labels)
#    1161 # NOTE: if we do not give columns, order of above will be arbitrary
#    1162 dfbeta = DataFrame(self.dfbetas, columns=beta_labels,
#    1163                    index=row_labels)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:815, in OLSInfluence.resid_studentized_external(self)
#     807 @cache_readonly
#     808 def resid_studentized_external(self):
#     809     """Studentized residuals using LOOO variance
#     810
#     811     this uses sigma from leave-one-out estimates
#     812
#     813     requires leave one out loop for observations
#     814     """
# --> 815     sigma_looo = np.sqrt(self.sigma2_not_obsi)
#     816     return self.get_resid_studentized_external(sigma=sigma_looo)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:950, in OLSInfluence.sigma2_not_obsi(self)
#     942 @cache_readonly
#     943 def sigma2_not_obsi(self):
#     944     """error variance for all LOOO regressions
#     945
#     946     This is 'mse_resid' from each auxiliary regression.
#     947
#     948     uses results from leave-one-observation-out loop
#     949     """
# --> 950     return np.asarray(self._res_looo['mse_resid'])
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:1110, in OLSInfluence._res_looo(self)
#    1108 cv_iter = LeaveOneOut(self.nobs)
#    1109 for inidx, outidx in cv_iter:
# -> 1110     res_i = self.model_class(endog[inidx], exog[inidx]).fit()
#    1111     params[outidx] = res_i.params
#    1112     mse_resid[outidx] = res_i.mse_resid
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/regression/linear_model.py:335, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     330 if method == "pinv":
#     331     if not (hasattr(self, 'pinv_wexog') and
#     332             hasattr(self, 'normalized_cov_params') and
#     333             hasattr(self, 'rank')):
# --> 335         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     336         self.normalized_cov_params = np.dot(
#     337             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     339         # Cache these singular values for use later.
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tools/tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/linalg/linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
df2['transmission'].unique()
# Out:
# array([0, 1])

# %%
df2['max_power'].unique()
# Out:
# array([ 74.   , 103.52 ,  78.   ,  90.   ,  88.2  ,  81.86 ,  57.5  ,
#         37.   ,  67.1  ,  68.1  , 108.45 ,  60.   ,  73.9  ,  67.   ,
#         82.   ,  88.5  ,  46.3  ,  88.73 ,  64.1  ,  98.6  ,  88.8  ,
#         83.81 ,  83.1  ,  47.3  ,  73.8  ,  34.2  ,  35.   ,  81.83 ,
#         40.3  , 121.3  , 138.03 , 160.77 , 117.3  , 116.3  ,  83.14 ,
#         67.05 , 100.   , 120.7  ,  98.63 , 175.56 , 103.25 , 171.5  ,
#        100.6  , 174.33 , 187.74 , 170.   ,  78.9  ,  88.76 ,  86.8  ,
#        108.495, 108.62 ,  93.7  , 103.6  ,  98.59 , 189.   ,  67.04 ,
#         68.05 ,  58.2  ,  82.85 ,  81.8  ,  73.   , 120.   ,  94.68 ,
#        160.   ,  65.   , 155.   ,  69.01 , 126.32 , 138.1  ,  83.8  ,
#        126.2  ,  98.96 ,  62.1  ,  86.7  , 177.   , 177.46 , 141.   ,
#        117.6  , 190.   , 150.   , 147.5  , 108.5  , 103.5  , 183.   ,
#        181.04 , 157.7  , 164.7  ,  91.1  ,  68.   ,  75.   ,  85.8  ,
#         87.2  ,  53.   , 118.   , 103.2  ,  83.   ,  84.   ,  58.16 ,
#        147.94 ,  74.02 ,  53.3  ,  80.   ,  88.7  ,  97.7  , 121.36 ,
#        162.   , 140.   ,  94.   , 100.57 ,  82.9  ,  83.11 ,  70.   ,
#        153.86 , 121.   , 126.3  ,  73.97 ,  69.   ,  99.6  , 102.   ,
#        105.   ,  63.   ,  79.4  ,  97.9  ,  63.1  ,  66.1  , 110.   ,
#        174.5  ,  53.26 ,  73.75 ,  67.06 ,  64.08 ,  37.5  , 189.3  ,
#        158.8  ,  61.7  ,  55.2  ,  71.01 ,  73.74 , 147.9  ,  71.   ,
#         77.   , 121.4  , 113.4  ,  47.   , 130.   ,  57.6  , 138.   ,
#         52.8  ,  53.64 ,  53.5  ,  76.8  ,  82.4  , 113.42 ,  76.   ,
#         84.8  ,  56.3  , 112.   ,  92.   , 105.5  ,  95.   ,  72.4  ,
#        115.   , 152.   ,  91.2  ,  74.9  ,  62.   , 105.3  ,  73.94 ,
#         85.   , 118.3  ,  72.   , 147.51 ,  58.   ,  64.   , 126.24 ,
#         76.9  , 194.3  ,  99.23 ,  89.84 , 123.7  , 118.35 ,  99.   ,
#        136.   , 104.68 ,  37.48 , 104.   ,  63.12 ,  91.7  , 102.5  ,
#        177.6  ,  45.   , 123.37 , 147.8  , 184.   ,  84.48 ,  68.07 ,
#         74.96 , 167.6  , 152.87 , 112.2  ,  83.83 , 110.4  , 104.55 ,
#        103.   , 103.3  ,  66.   , 108.6  , 163.7  ,  94.93 , 127.   ,
#        179.5  , 120.69 , 121.31 , 138.08 , 187.7  ,  80.8  ,  86.79 ,
#         93.87 , 116.6  , 143.   ,  92.7  ,  88.   ,  58.33 ,  78.8  ,
#         64.4  , 125.   , 139.01 , 181.   ,  55.23 , 157.75 , 101.   ,
#        186.   , 187.4  ,  64.9  , 148.   ,  35.5  ,  89.75 ,  32.8  ,
#         91.72 , 106.   ,  98.97 ,  66.6  ,  86.   ,  65.3  ,  98.82 ,
#         38.   , 142.   , 132.   , 178.   , 163.2  , 177.5  , 175.   ,
#         57.   ,  80.84 , 167.67 , 170.63 ,  52.   , 149.5  , 188.   ,
#         48.21 , 165.   , 100.5  , 144.   , 104.5  , 103.26 , 116.4  ,
#         98.79 ,  80.9  ,  58.3  , 198.25 , 167.62 , 139.46 , 158.   ,
#        110.5  ,  82.5  , 141.1  ,  38.4  , 197.2  , 122.4  , 134.1  ,
#         60.2  , 134.   , 135.1  ])

# %%
transmission_d = pd.get_dummies(df2.transmission, dtype=int)
transmission_d.rename(columns = {0: 'Easy', 1: 'Hard'}, inplace = True)
df2 = pd.concat([df2,transmission_d], axis=1)

# %%
fuel_d = pd.get_dummies(df2.fuel, dtype=int)
fuel_d = pd.concat([df2,fuel_d], axis=1)

# %%
df2['fuel'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
results = ols("selling_price ~ transmission +km_driven +mileage + max_power + fuel + seller_type", data= df2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          selling_price   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     2295.
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):               0.00
# Time:                        03:41:47   Log-Likelihood:            -1.0610e+05
# No. Observations:                7611   AIC:                         2.122e+05
# Df Residuals:                    7604   BIC:                         2.123e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -2.597e+05   3.42e+04     -7.601      0.000   -3.27e+05   -1.93e+05
# transmission  3.048e+05    1.2e+04     25.424      0.000    2.81e+05    3.28e+05
# km_driven       -2.3706      0.079    -29.993      0.000      -2.526      -2.216
# mileage       1.049e+04    916.613     11.445      0.000    8694.115    1.23e+04
# max_power     9304.9447    140.210     66.364      0.000    9030.094    9579.795
# fuel         -1.303e+05   6856.979    -19.005      0.000   -1.44e+05   -1.17e+05
# seller_type   8.568e+04   7325.228     11.697      0.000    7.13e+04       1e+05
# ==============================================================================
# Omnibus:                     1999.876   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12733.290
# Skew:                           1.104   Prob(JB):                         0.00
# Kurtosis:                       8.940   Cond. No.                     9.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df2['year'] = pd.to_datetime(df2['date'])

# %%
#Resampling data set by 2 days
daily_dataset = df2.set_index('date').resample("2D").agg({'selling_price':'mean','transmission':'mean','km_driven':'mean', 'mileage':'mean','max_power':'mean'}).ffill()

# %%
daily_dataset
# Out:
#             selling_price  transmission     km_driven    mileage  max_power
# date
# 1970-01-01  540101.206149      0.105768  68974.133097  19.561447  87.858149

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso

# %%
categorical_features = ['transmission']
numerical_features = ['km_driven','mileage', 'max_power']
target = 'selling_price'

# %%
X_train, X_test, y_train, y_test = train_test_split(df2[categorical_features + numerical_features]
                                                    ,df2[target],
                                                    test_size = 0.3, random_state=1234)

# %%
cat_transformer = Pipeline(steps = [('onehot', OneHotEncoder(handle_unknown='ignore'))])
num_transformer = Pipeline(steps = [('scaler', StandardScaler())])

# %%
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, categorical_features),
                                                 ('num', num_transformer, numerical_features)])

# %%
linear_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
linear_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['transmission']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['km_driven', 'mileage',
#                                                    'max_power'])])),
#                 ('regressor', LinearRegression())])

# %%
pred = linear_regression.predict(X_test)

# %%
pred
# Out:
# array([478576., 762672., 359904., ..., 817664., 225104., 395040.])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(pred,y_test))
# Out:
# 285106.8507849325

# %%
ridge_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Ridge(alpha=3.0))
])

# %%
ridge_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['transmission']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['km_driven', 'mileage',
#                                                    'max_power'])])),
#                 ('regressor', Ridge(alpha=3.0))])

# %%
pred_ridge = ridge_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(pred_ridge,y_test))
# Out:
# 284971.6676066201

# %%
lasso_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Lasso(alpha=1.0))
])

# %%
lasso_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['transmission']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['km_driven', 'mileage',
#                                                    'max_power'])])),
#                 ('regressor', Lasso())])

# %%
lasso_pred = lasso_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(lasso_pred, y_test))
# Out:
# 284950.2033041507

# %%
elasticnet_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', ElasticNet(alpha=1.0, l1_ratio=0.8))
])

# %%
elasticnet_regression.fit(X_train, y_train)
elasticnet_pred = elasticnet_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(elasticnet_pred, y_test))
# Out:
# 298182.6830574334

# %%
elastic_net_pred = pd.concat([pd.DataFrame(elasticnet_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)

# %%
elastic_net_pred['res'] = elastic_net_pred['pred'] - elastic_net_pred['selling_price']

# %%
plt.scatter(X_test['transmission'],elastic_net_pred['res'])

# %%
lasso_net_pred = pd.concat([pd.DataFrame(lasso_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)

# %%
lasso_net_pred['res'] = lasso_net_pred['pred'] - lasso_net_pred['selling_price']

plt.scatter(X_test['mileage'],lasso_net_pred['res'])

# %%
ridge_net_pred = pd.concat([pd.DataFrame(pred_ridge).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)
ridge_net_pred['res'] = ridge_net_pred['pred'] - ridge_net_pred['selling_price']
plt.scatter(X_test['mileage'],ridge_net_pred['res'])
